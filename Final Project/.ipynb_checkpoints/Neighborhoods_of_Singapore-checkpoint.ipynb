# %% [markdown]
# <font size="4">Creating dataframe of Singaporean districts and their coordinates.</font>

# %% [markdown]
# Let us first create a dataframe that contains the districts of Singapore and their coordinates by scraping the data from Wikipedia.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import geocoder # import geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
import json # library to handle JSON files
import numpy as np

url = "https://en.wikipedia.org/wiki/Planning_Areas_of_Singapore" #Url of Wikipedia page with Toronto neighborhoods and postal codes
data  = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")
tables = soup.find_all('table') #Find tables in the html
planningArea_data = pd.DataFrame(columns=["Planning Area","Latitude","Longitude"])
for row in tables[2].tbody.find_all("tr"):    
    col =row.td
    if col != None:
        planningArea = col.text.strip()
        geolocator = Nominatim(user_agent="sg_explorer")
        address = '{}, SG'.format(planningArea)
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        planningArea_data = planningArea_data.append({"Planning Area": planningArea,"Latitude": latitude,"Longitude" : longitude}, ignore_index=True)

# %% [markdown]
# Create a map of Singapore and show all the districts.

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
for lat, lng, neighborhood in zip(planningArea_data["Latitude"], planningArea_data["Longitude"], planningArea_data["Planning Area"]):
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_916c421010564b68aff6dedc846526a1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_916c421010564b68aff6dedc846526a1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_916c421010564b68aff6dedc846526a1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_916c421010564b68aff6dedc846526a1%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Define Foursquare credentials

# %%
CLIENT_ID = 'IRKFWJXIIWOMSCV1EBIGSM4C1ODUR1V1WB4XXDKUARYY4WXH' # your Foursquare ID
CLIENT_SECRET = '0B4YEAJQNMY3Y02RUNAWKD0VEX2CD4Q25UH4WPALOSHHNDUU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# <font size="4">Exploring the first district in the planningArea_data Dataframe</font>

# %%
print("The first district in the dataframe is {}.".format(planningArea_data.loc[0, "Planning Area"]))
# Out:
# The first district in the dataframe is Ang Mo Kio.

# %%
neighborhood_latitude = planningArea_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = planningArea_data.loc[0, 'Longitude'] # neighborhood longitude value

latitude = neighborhood_latitude
longitude = neighborhood_longitude
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6132c7284b234128eada83b3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Ang Mo Kio',
#   'headerFullLocation': 'Ang Mo Kio, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 41,
#   'suggestedBounds': {'ne': {'lat': 1.3745803045000045,
#     'lng': 103.85401568693963},
#    'sw': {'lat': 1.3655802954999954, 'lng': 103.84502991306037}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b15f661f964a52012b623e3',
#        'name': 'FairPrice Xtra',
#        'location': {'address': '#B2-26 AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3692792884081397,
#         'lng': 103.84888576818767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692792884081397,
#           'lng': 103.84888576818767}],
#         'distance': 113,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-26 AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b15f661f964a52012b623e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc30123abf495215220c393',
#        'name': 'Old Chang Kee',
#        'location': {'address': 'AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Avenue 3',
#         'lat': 1.369093882325005,
#         'lng': 103.84838865753792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369093882325005,
#           'lng': 103.84838865753792}],
#         'distance': 167,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['AMK Hub (53 Ang Mo Kio Avenue 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc30123abf495215220c393-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ea04ff964a520e21c24e3',
#        'name': 'MOS Burger',
#        'location': {'address': '#01-33, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369170234303566,
#         'lng': 103.84783132985862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369170234303566,
#           'lng': 103.84783132985862}],
#         'distance': 213,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-33, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1ea04ff964a520e21c24e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d48d8dfdae4eb0008d85e5a',
#        'name': 'A&W',
#        'location': {'address': '#B1-51/51A AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369541,
#         'lng': 103.849043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369541,
#           'lng': 103.849043}],
#         'distance': 80,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-51/51A AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d48d8dfdae4eb0008d85e5a-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bceddaeb6c49c7410bb9791',
#        'name': 'Subway',
#        'location': {'address': '#01-35 AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691362071202464,
#         'lng': 103.8476121994989,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691362071202464,
#           'lng': 103.8476121994989}],
#         'distance': 237,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-35 AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bceddaeb6c49c7410bb9791-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b06a9c8f964a52059ee22e3',
#        'name': 'Pepper Lunch',
#        'location': {'address': '#01-34, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691073953750246,
#         'lng': 103.84779052779332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691073953750246,
#           'lng': 103.84779052779332}],
#         'distance': 221,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-34, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b06a9c8f964a52059ee22e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ece4dd693ad987b4a9fb4ef',
#        'name': 'NTUC FairPrice',
#        'location': {'address': 'Blk 712 Ang Mo Kio Ave 6 #01-4056',
#         'lat': 1.3715067580283722,
#         'lng': 103.84708243348618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3715067580283722,
#           'lng': 103.84708243348618}],
#         'distance': 314,
#         'postalCode': '560712',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 712 Ang Mo Kio Ave 6 #01-4056',
#          '560712',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ece4dd693ad987b4a9fb4ef-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b56f605364d97002c7cada9',
#        'name': 'Playmade by 丸作',
#        'location': {'lat': 1.3692572280858266,
#         'lng': 103.84972276286534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692572280858266,
#           'lng': 103.84972276286534}],
#         'distance': 94,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b56f605364d97002c7cada9-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4e516aa8fba143cab6421a',
#        'name': 'Phoon Huat & Co (Pte) Ltd',
#        'location': {'address': '422 Ang Mo Kio Ave 3, #01-2526',
#         'lat': 1.3683177603071388,
#         'lng': 103.85163895414827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3683177603071388,
#           'lng': 103.85163895414827}],
#         'distance': 306,
#         'postalCode': '560422',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['422 Ang Mo Kio Ave 3, #01-2526',
#          '560422',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4e516aa8fba143cab6421a-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5667cf6201e21ef369046d',
#        'name': 'Coffee Shop, Block 422, Ang Mo Kio Ave 3',
#        'location': {'lat': 1.3681191753269961,
#         'lng': 103.85109286908205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3681191753269961,
#           'lng': 103.85109286908205}],
#         'distance': 279,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5667cf6201e21ef369046d-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b08bbdbf964a5209a1123e3',
#        'name': 'Fitness First',
#        'location': {'address': '#B1-36, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369249484168252,
#         'lng': 103.84858429733478,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369249484168252,
#           'lng': 103.84858429733478}],
#         'distance': 139,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-36, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b08bbdbf964a5209a1123e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c68f51498efd710da56841',
#        'name': 'e品红麻辣香锅 Mala Hot Pot',
#        'location': {'address': 'S11 Ang Mo Kio',
#         'lat': 1.3714982901834443,
#         'lng': 103.84780316423276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3714982901834443,
#           'lng': 103.84780316423276}],
#         'distance': 248,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['S11 Ang Mo Kio', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c68f51498efd710da56841-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e61bc951f6ef7d07a688717',
#        'name': 'ST31 Coffee Shop',
#        'location': {'address': '347 Ang Mo Kio Avenue 3',
#         'lat': 1.3674777858660376,
#         'lng': 103.84833363275743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3674777858660376,
#           'lng': 103.84833363275743}],
#         'distance': 318,
#         'postalCode': '560347',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['347 Ang Mo Kio Avenue 3',
#          '560347',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e61bc951f6ef7d07a688717-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50712b67e4b0548504446dea',
#        'name': 'Face Ban Mian 非板面 (Ang Mo Kio)',
#        'location': {'address': '722 Ang Mo Kio Ave 8',
#         'crossStreet': 'Ang Mo Kio Central',
#         'lat': 1.3720308862082362,
#         'lng': 103.84750442817865,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3720308862082362,
#           'lng': 103.84750442817865}],
#         'distance': 312,
#         'postalCode': '560722',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['722 Ang Mo Kio Ave 8 (Ang Mo Kio Central)',
#          '560722',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50712b67e4b0548504446dea-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b6bef7cb9a5a8002c117506',
#        'name': 'Starbucks',
#        'location': {'address': '#B1-65, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3692298000769514,
#         'lng': 103.84868271780437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692298000769514,
#           'lng': 103.84868271780437}],
#         'distance': 133,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-65, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b6bef7cb9a5a8002c117506-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5eef6df964a5208b9e29e3',
#        'name': 'PLAYe',
#        'location': {'address': '#02-30/31, AMK HUB',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691085357692998,
#         'lng': 103.84822546074516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691085357692998,
#           'lng': 103.84822546074516}],
#         'distance': 180,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-30/31, AMK HUB (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fb941735',
#          'name': 'Hobby Shop',
#          'pluralName': 'Hobby Shops',
#          'shortName': 'Hobbies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5eef6df964a5208b9e29e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57662f0f498e7856b64833be',
#        'name': "Collin's Grille . Bento",
#        'location': {'address': 'Ang Mo Kio Central',
#         'crossStreet': 'Jubilee Sq',
#         'lat': 1.3717133895413027,
#         'lng': 103.84752638869986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3717133895413027,
#           'lng': 103.84752638869986}],
#         'distance': 287,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Central (Jubilee Sq)', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57662f0f498e7856b64833be-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53300a03498ec51f067f0f70',
#        'name': 'Bun Master',
#        'location': {'address': 'Ang Mo Kio Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3692421789361022,
#         'lng': 103.8490310616258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692421789361022,
#           'lng': 103.8490310616258}],
#         'distance': 108,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53300a03498ec51f067f0f70-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f76d0c0e4b01af71245368a',
#        'name': 'LiHO',
#        'location': {'address': '#02-66 AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691032014108975,
#         'lng': 103.84824143272056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691032014108975,
#           'lng': 103.84824143272056}],
#         'distance': 179,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-66 AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f76d0c0e4b01af71245368a-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5687adf3498e2cded5e88837',
#        'name': 'Takagi Ramen',
#        'location': {'address': '51 Ang Mo Kio Ave 3 #01-01C',
#         'crossStreet': 'Broadway Coffee Shop',
#         'lat': 1.3692634,
#         'lng': 103.847046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692634,
#           'lng': 103.847046}],
#         'distance': 290,
#         'postalCode': '560721',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['51 Ang Mo Kio Ave 3 #01-01C (Broadway Coffee Shop)',
#          '560721',
#          'Singapore']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5687adf3498e2cded5e88837-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ea142f964a520001d24e3',
#        'name': 'Cathay Cineplexes',
#        'location': {'address': 'Level 4, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3693207810230712,
#         'lng': 103.8487183124522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3693207810230712,
#           'lng': 103.8487183124522}],
#         'distance': 123,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Level 4, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1ea142f964a520001d24e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515ace52e4b0cc51344f4eb4',
#        'name': 'Lao Ban Soya Beancurd 老伴豆花',
#        'location': {'address': '#01-03 Jubilee Sq',
#         'crossStreet': '61 Ang Mo Kio Ave 8',
#         'lat': 1.3716845960108295,
#         'lng': 103.8479733775373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3716845960108295,
#           'lng': 103.8479733775373}],
#         'distance': 248,
#         'postalCode': '569814',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-03 Jubilee Sq (61 Ang Mo Kio Ave 8)',
#          '569814',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515ace52e4b0cc51344f4eb4-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b68711556bfb775ff0093',
#        'name': 'POSB Ang Mo Kio Central Branch',
#        'location': {'address': '712A Ang Mo Kio Ave 6 #01-4066',
#         'lat': 1.3709690879855922,
#         'lng': 103.847341485289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3709690879855922,
#           'lng': 103.847341485289}],
#         'distance': 262,
#         'postalCode': '560712',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['712A Ang Mo Kio Ave 6 #01-4066',
#          '560712',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b68711556bfb775ff0093-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f77455498e868c8f2bbbbb',
#        'name': 'True Fitness',
#        'location': {'address': '#04-01, Djitsun Mall, 5 Ang Mo Kio Central 2',
#         'crossStreet': 'Ang Mo Kio Ave 8',
#         'lat': 1.372891267012976,
#         'lng': 103.847660805816,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.372891267012976,
#           'lng': 103.847660805816}],
#         'distance': 375,
#         'postalCode': '569663',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#04-01, Djitsun Mall, 5 Ang Mo Kio Central 2 (Ang Mo Kio Ave 8)',
#          '569663',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51f77455498e868c8f2bbbbb-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b15f0dcf964a520e3b523e3',
#        'name': 'AMK Hub',
#        'location': {'address': '53 Ang Mo Kio Ave. 3',
#         'crossStreet': 'Ang Mo Kio Ave. 8',
#         'lat': 1.3692465509537302,
#         'lng': 103.84852453593467,
#         'distance': 144,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['53 Ang Mo Kio Ave. 3 (Ang Mo Kio Ave. 8)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b15f0dcf964a520e3b523e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7fce65f964a520903e30e3',
#        'name': 'AMK 347 Food House',
#        'location': {'address': '347, Ang Mo Kio Avenue 3',
#         'lat': 1.367601595486527,
#         'lng': 103.84837187141285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.367601595486527,
#           'lng': 103.84837187141285}],
#         'distance': 304,
#         'postalCode': '560347',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['347, Ang Mo Kio Avenue 3',
#          '560347',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7fce65f964a520903e30e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5be2d3831af8520039a38da2',
#        'name': 'Malaysia Boleh!',
#        'location': {'address': '#B2-41/42, Ang Mo Kio Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3694410017744636,
#         'lng': 103.84906566043585,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3694410017744636,
#           'lng': 103.84906566043585}],
#         'distance': 87,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-41/42, Ang Mo Kio Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5be2d3831af8520039a38da2-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2d720875579521e9735d83',
#        'name': 'Watsons',
#        'location': {'address': '#B1-39 to 41, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3693816236732865,
#         'lng': 103.84921372306107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3693816236732865,
#           'lng': 103.84921372306107}],
#         'distance': 85,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-39 to 41, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2d720875579521e9735d83-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0a18e6f964a520c02123e3',
#        'name': 'Xi Xiang Feng Yong Tau Foo 喜相逢酿豆腐',
#        'location': {'address': 'Ang Mo Kio Central Market & Food Centre, #01-23',
#         'crossStreet': '724 Ang Mo Kio Avenue 6',
#         'lat': 1.3719750629461769,
#         'lng': 103.8464082321786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3719750629461769,
#           'lng': 103.8464082321786}],
#         'distance': 405,
#         'postalCode': '560724',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Central Market & Food Centre, #01-23 (724 Ang Mo Kio Avenue 6)',
#          '560724',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0a18e6f964a520c02123e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a3c90340720a1970b8693',
#        'name': 'Express Teppan-Yaki',
#        'location': {'address': 'AMK Hub',
#         'lat': 1.3691372852995798,
#         'lng': 103.84823193982062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691372852995798,
#           'lng': 103.84823193982062}],
#         'distance': 177,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['AMK Hub', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a3c90340720a1970b8693-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5799ecad498ec6d503ab8a53',
#        'name': 'Mr Teh Tarik',
#        'location': {'address': 'Blk 728 Ang Mo Kio Avenue 6',
#         'crossStreet': 'Ang Mo Kio Central',
#         'lat': 1.3721677783775261,
#         'lng': 103.84560223678665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3721677783775261,
#           'lng': 103.84560223678665}],
#         'distance': 494,
#         'postalCode': '560728',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 728 Ang Mo Kio Avenue 6 (Ang Mo Kio Central)',
#          '560728',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ff',
#          'name': 'Halal Restaurant',
#          'pluralName': 'Halal Restaurants',
#          'shortName': 'Halal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5799ecad498ec6d503ab8a53-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8c51a0f964a5204dca32e3',
#        'name': 'Cheers',
#        'location': {'address': '#01-07, Ang Mo Kio MRT Station',
#         'crossStreet': 'Ang Mo Kio Ave 3',
#         'lat': 1.3692634112819182,
#         'lng': 103.84977668523788,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692634112819182,
#           'lng': 103.84977668523788}],
#         'distance': 95,
#         'postalCode': '569811',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-07, Ang Mo Kio MRT Station (Ang Mo Kio Ave 3)',
#          '569811',
#          'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8c51a0f964a5204dca32e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5213643e11d236c03cd2810f',
#        'name': "Swensen's",
#        'location': {'address': '#B1-25/26, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave. 3',
#         'lat': 1.3691117290772925,
#         'lng': 103.84771817813137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691117290772925,
#           'lng': 103.84771817813137}],
#         'distance': 227,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-25/26, AMK Hub (53 Ang Mo Kio Ave. 3)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5213643e11d236c03cd2810f-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd0300cadf29c74238b7b95',
#        'name': 'Yunus N Family',
#        'location': {'address': '#01-01 Ang Mo Kio Central Food Centre',
#         'crossStreet': '724 Ang Mo Kio Ave 6',
#         'lat': 1.3716603267595933,
#         'lng': 103.8463755962762,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3716603267595933,
#           'lng': 103.8463755962762}],
#         'distance': 391,
#         'postalCode': '560724',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Ang Mo Kio Central Food Centre (724 Ang Mo Kio Ave 6)',
#          '560724',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd0300cadf29c74238b7b95-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c657dabe2ee9c749ce32d2f',
#        'name': 'Ang Mo Kio Central Market & Food Centre',
#        'location': {'address': '724 Ang Mo Kio Avenue 6',
#         'lat': 1.372036962033785,
#         'lng': 103.84636606706158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.372036962033785,
#           'lng': 103.84636606706158}],
#         'distance': 413,
#         'postalCode': '560724',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['724 Ang Mo Kio Avenue 6',
#          '560724',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c657dabe2ee9c749ce32d2f-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b666f95f964a52058212be3',
#        'name': 'Popeyes Louisiana Kitchen',
#        'location': {'address': '61 Ang Mo Kio Ave 8 #01-00',
#         'crossStreet': 'Jubilee Sq',
#         'lat': 1.371654846551403,
#         'lng': 103.84800842657619,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.371654846551403,
#           'lng': 103.84800842657619}],
#         'distance': 243,
#         'postalCode': '569814',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['61 Ang Mo Kio Ave 8 #01-00 (Jubilee Sq)',
#          '569814',
#          'Singapore']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b666f95f964a52058212be3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d490174f53c8cfa19c41247',
#        'name': 'Umi Sushi',
#        'location': {'address': '#B2-11, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3694055476931515,
#         'lng': 103.84930516535186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3694055476931515,
#           'lng': 103.84930516535186}],
#         'distance': 78,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-11, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d490174f53c8cfa19c41247-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1e9fabf964a520cf1c24e3',
#        'name': 'Fish & Co.',
#        'location': {'address': '#02-03, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3690773713959834,
#         'lng': 103.84908088946379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3690773713959834,
#           'lng': 103.84908088946379}],
#         'distance': 121,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-03, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1e9fabf964a520cf1c24e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d23ed07836f5481bc403ff7',
#        'name': 'LiHO',
#        'location': {'address': '#01-14 Jubilee Square',
#         'crossStreet': '61 Ang Mo Kio Ave 8',
#         'lat': 1.3715925436856207,
#         'lng': 103.84786263454394,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3715925436856207,
#           'lng': 103.84786263454394}],
#         'distance': 249,
#         'postalCode': '569814',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-14 Jubilee Square (61 Ang Mo Kio Ave 8)',
#          '569814',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d23ed07836f5481bc403ff7-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9392f3f964a520d54834e3',
#        'name': 'Hong Kong Dessert',
#        'location': {'address': 'Jubilee Entertainment Hall',
#         'crossStreet': '61 Ang Mo Kio Ave 8',
#         'lat': 1.3716722755967306,
#         'lng': 103.84805899124987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3716722755967306,
#           'lng': 103.84805899124987}],
#         'distance': 240,
#         'postalCode': '569814',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jubilee Entertainment Hall (61 Ang Mo Kio Ave 8)',
#          '569814',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9392f3f964a520d54834e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5285f3cd11d2b6a8411ecef4',
#        'name': 'Broadway Coffeeshop',
#        'location': {'address': 'Blk 727 Ang Mo Kio Ave 6',
#         'lat': 1.3730720409991226,
#         'lng': 103.84639344910318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3730720409991226,
#           'lng': 103.84639344910318}],
#         'distance': 481,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 727 Ang Mo Kio Ave 6', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5285f3cd11d2b6a8411ecef4-40'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#              name            categories       lat         lng
# 0  FairPrice Xtra           Supermarket  1.369279  103.848886
# 1   Old Chang Kee           Snack Place  1.369094  103.848389
# 2      MOS Burger          Burger Joint  1.369170  103.847831
# 3             A&W  Fast Food Restaurant  1.369541  103.849043
# 4          Subway        Sandwich Place  1.369136  103.847612

# %% [markdown]
# <font size="4">Exploring the districts of Singapore</font>

# %% [markdown]
# First, define a function that can be used to search for venues in each district of Singapore.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
singapore_venues=getNearbyVenues(list(planningArea_data["Planning Area"]),list(planningArea_data['Latitude']),list(planningArea_data['Longitude']))
print(singapore_venues.shape)
singapore_venues.head()
# Out:
# Ang Mo Kio
# Bedok
# Bishan
# Boon Lay
# Bukit Batok
# Bukit Merah
# Bukit Panjang
# Bukit Timah
# Central Water Catchment
# Changi
# Changi Bay
# Choa Chu Kang
# Clementi
# Downtown Core
# Geylang
# Hougang
# Jurong East
# Jurong West
# Kallang
# Lim Chu Kang
# Mandai
# Marina East
# Marina South
# Marine Parade
# Museum
# Newton
# North-Eastern Islands
# Novena
# Orchard
# Outram
# Pasir Ris
# Paya Lebar
# Pioneer
# Punggol
# Queenstown
# River Valley
# Rochor
# Seletar
# Sembawang
# Sengkang
# Serangoon
# Simpang
# Singapore River
# Southern Islands
# Straits View
# Sungei Kadut
# Tampines
# Tanglin
# Tengah
# Toa Payoh
# Tuas
# Western Islands
# Western Water Catchment
# Woodlands
# Yishun
# (1647, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude           Venue  \
# 0   Ang Mo Kio                1.37008              103.849523  FairPrice Xtra
# 1   Ang Mo Kio                1.37008              103.849523   Old Chang Kee
# 2   Ang Mo Kio                1.37008              103.849523      MOS Burger
# 3   Ang Mo Kio                1.37008              103.849523             A&W
# 4   Ang Mo Kio                1.37008              103.849523          Subway
#
#    Venue Latitude  Venue Longitude        Venue Category
# 0        1.369279       103.848886           Supermarket
# 1        1.369094       103.848389           Snack Place
# 2        1.369170       103.847831          Burger Joint
# 3        1.369541       103.849043  Fast Food Restaurant
# 4        1.369136       103.847612        Sandwich Place

# %% [markdown]
# This dataframe contains over 1600 venues. Let us check the number of venues found in each district.

# %%
singapore_venues.groupby('Neighborhood').count()
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Ang Mo Kio                                  41                      41     41
# Bedok                                       60                      60     60
# Bishan                                      44                      44     44
# Boon Lay                                    72                      72     72
# Bukit Batok                                 19                      19     19
# Bukit Merah                                 23                      23     23
# Bukit Panjang                               46                      46     46
# Bukit Timah                                 11                      11     11
# Central Water Catchment                      3                       3      3
# Changi                                       6                       6      6
# Changi Bay                                   6                       6      6
# Choa Chu Kang                               20                      20     20
# Clementi                                    65                      65     65
# Downtown Core                               55                      55     55
# Geylang                                     31                      31     31
# Hougang                                     35                      35     35
# Jurong East                                 72                      72     72
# Jurong West                                 64                      64     64
# Kallang                                      4                       4      4
# Lim Chu Kang                                 3                       3      3
# Mandai                                       1                       1      1
# Marina East                                  4                       4      4
# Marina South                                 5                       5      5
# Marine Parade                               37                      37     37
# Museum                                      36                      36     36
# Newton                                      28                      28     28
# Novena                                      63                      63     63
# Orchard                                    100                     100    100
# Outram                                      12                      12     12
# Pasir Ris                                   31                      31     31
# Paya Lebar                                  78                      78     78
# Pioneer                                     16                      16     16
# Punggol                                     40                      40     40
# Queenstown                                  16                      16     16
# River Valley                                20                      20     20
# Rochor                                      26                      26     26
# Seletar                                      4                       4      4
# Sembawang                                   23                      23     23
# Sengkang                                    30                      30     30
# Serangoon                                   38                      38     38
# Simpang                                      1                       1      1
# Singapore River                            100                     100    100
# Straits View                                 1                       1      1
# Sungei Kadut                                 3                       3      3
# Tampines                                    86                      86     86
# Tanglin                                     23                      23     23
# Toa Payoh                                   47                      47     47
# Tuas                                         3                       3      3
# Western Water Catchment                      1                       1      1
# Woodlands                                   51                      51     51
# Yishun                                      43                      43     43
#
#                          Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Ang Mo Kio                           41               41              41
# Bedok                                60               60              60
# Bishan                               44               44              44
# Boon Lay                             72               72              72
# Bukit Batok                          19               19              19
# Bukit Merah                          23               23              23
# Bukit Panjang                        46               46              46
# Bukit Timah                          11               11              11
# Central Water Catchment               3                3               3
# Changi                                6                6               6
# Changi Bay                            6                6               6
# Choa Chu Kang                        20               20              20
# Clementi                             65               65              65
# Downtown Core                        55               55              55
# Geylang                              31               31              31
# Hougang                              35               35              35
# Jurong East                          72               72              72
# Jurong West                          64               64              64
# Kallang                               4                4               4
# Lim Chu Kang                          3                3               3
# Mandai                                1                1               1
# Marina East                           4                4               4
# Marina South                          5                5               5
# Marine Parade                        37               37              37
# Museum                               36               36              36
# Newton                               28               28              28
# Novena                               63               63              63
# Orchard                             100              100             100
# Outram                               12               12              12
# Pasir Ris                            31               31              31
# Paya Lebar                           78               78              78
# Pioneer                              16               16              16
# Punggol                              40               40              40
# Queenstown                           16               16              16
# River Valley                         20               20              20
# Rochor                               26               26              26
# Seletar                               4                4               4
# Sembawang                            23               23              23
# Sengkang                             30               30              30
# Serangoon                            38               38              38
# Simpang                               1                1               1
# Singapore River                     100              100             100
# Straits View                          1                1               1
# Sungei Kadut                          3                3               3
# Tampines                             86               86              86
# Tanglin                              23               23              23
# Toa Payoh                            47               47              47
# Tuas                                  3                3               3
# Western Water Catchment               1                1               1
# Woodlands                            51               51              51
# Yishun                               43               43              43

# %% [markdown]
# <font size="4">Types of venues in each neighborhood.</font>

# %% [markdown]
# Next, we would like to see what kinds of venues are most common in each Singapore neighborhood. First, we perform one-hot encoding for each venue.

# %%
# one hot encoding
singapore_onehot = pd.get_dummies(singapore_venues[['Venue Category']], prefix="", prefix_sep="")
singapore_onehot.drop(['Neighborhood'], axis=1,inplace = True)
singapore_onehot.insert(loc=0, column='Neighborhood', value=singapore_venues['Neighborhood'] )

# %% [markdown]
# Next, group the venues by their neighborhoods and calculate the mean frequency for each venue category.

# %%
singapore_grouped = singapore_onehot.groupby('Neighborhood').mean().reset_index()
singapore_grouped
# Out:
#                Neighborhood    ATM  Accessories Store   Airport  \
# 0                Ang Mo Kio  0.000           0.000000  0.000000
# 1                     Bedok  0.000           0.000000  0.000000
# 2                    Bishan  0.000           0.000000  0.000000
# 3                  Boon Lay  0.000           0.000000  0.000000
# 4               Bukit Batok  0.000           0.000000  0.000000
# 5               Bukit Merah  0.000           0.000000  0.000000
# 6             Bukit Panjang  0.000           0.000000  0.000000
# 7               Bukit Timah  0.000           0.000000  0.000000
# 8   Central Water Catchment  0.000           0.000000  0.000000
# 9                    Changi  0.000           0.000000  0.333333
# 10               Changi Bay  0.000           0.000000  0.000000
# 11            Choa Chu Kang  0.000           0.000000  0.000000
# 12                 Clementi  0.000           0.000000  0.000000
# 13            Downtown Core  0.000           0.000000  0.000000
# 14                  Geylang  0.000           0.000000  0.000000
# 15                  Hougang  0.000           0.000000  0.000000
# 16              Jurong East  0.000           0.013889  0.000000
# 17              Jurong West  0.000           0.000000  0.000000
# 18                  Kallang  0.000           0.000000  0.000000
# 19             Lim Chu Kang  0.000           0.000000  0.000000
# 20                   Mandai  0.000           0.000000  0.000000
# 21              Marina East  0.000           0.000000  0.000000
# 22             Marina South  0.000           0.000000  0.000000
# 23            Marine Parade  0.000           0.000000  0.000000
# 24                   Museum  0.000           0.000000  0.000000
# 25                   Newton  0.000           0.000000  0.000000
# 26                   Novena  0.000           0.000000  0.000000
# 27                  Orchard  0.000           0.000000  0.000000
# 28                   Outram  0.000           0.000000  0.000000
# 29                Pasir Ris  0.000           0.000000  0.000000
# 30               Paya Lebar  0.000           0.000000  0.000000
# 31                  Pioneer  0.000           0.000000  0.000000
# 32                  Punggol  0.025           0.000000  0.000000
# 33               Queenstown  0.000           0.000000  0.000000
# 34             River Valley  0.000           0.000000  0.000000
# 35                   Rochor  0.000           0.000000  0.000000
# 36                  Seletar  0.000           0.000000  0.000000
# 37                Sembawang  0.000           0.000000  0.000000
# 38                 Sengkang  0.000           0.000000  0.000000
# 39                Serangoon  0.000           0.000000  0.000000
# 40                  Simpang  0.000           0.000000  0.000000
# 41          Singapore River  0.000           0.000000  0.000000
# 42             Straits View  0.000           0.000000  0.000000
# 43             Sungei Kadut  0.000           0.000000  0.000000
# 44                 Tampines  0.000           0.000000  0.000000
# 45                  Tanglin  0.000           0.000000  0.000000
# 46                Toa Payoh  0.000           0.000000  0.000000
# 47                     Tuas  0.000           0.000000  0.000000
# 48  Western Water Catchment  0.000           0.000000  0.000000
# 49                Woodlands  0.000           0.000000  0.000000
# 50                   Yishun  0.000           0.000000  0.000000
#
#     American Restaurant    Arcade  Art Gallery  Art Museum  \
# 0              0.000000  0.000000     0.000000    0.000000
# 1              0.016667  0.000000     0.000000    0.000000
# 2              0.000000  0.000000     0.000000    0.000000
# 3              0.013889  0.000000     0.000000    0.000000
# 4              0.000000  0.000000     0.000000    0.000000
# 5              0.000000  0.000000     0.000000    0.000000
# 6              0.021739  0.000000     0.000000    0.000000
# 7              0.000000  0.000000     0.000000    0.000000
# 8              0.000000  0.000000     0.000000    0.000000
# 9              0.000000  0.000000     0.000000    0.000000
# 10             0.000000  0.000000     0.000000    0.000000
# 11             0.000000  0.000000     0.000000    0.000000
# 12             0.015385  0.000000     0.000000    0.000000
# 13             0.000000  0.000000     0.000000    0.000000
# 14             0.000000  0.000000     0.000000    0.000000
# 15             0.000000  0.000000     0.000000    0.000000
# 16             0.000000  0.000000     0.000000    0.000000
# 17             0.015625  0.000000     0.000000    0.000000
# 18             0.000000  0.000000     0.000000    0.000000
# 19             0.000000  0.000000     0.000000    0.000000
# 20             0.000000  0.000000     0.000000    0.000000
# 21             0.000000  0.000000     0.000000    0.000000
# 22             0.000000  0.000000     0.000000    0.000000
# 23             0.000000  0.000000     0.000000    0.000000
# 24             0.000000  0.000000     0.027778    0.027778
# 25             0.000000  0.000000     0.000000    0.000000
# 26             0.000000  0.000000     0.000000    0.000000
# 27             0.010000  0.000000     0.000000    0.000000
# 28             0.000000  0.000000     0.000000    0.000000
# 29             0.000000  0.000000     0.000000    0.000000
# 30             0.000000  0.000000     0.000000    0.000000
# 31             0.000000  0.000000     0.000000    0.000000
# 32             0.000000  0.000000     0.000000    0.000000
# 33             0.000000  0.000000     0.000000    0.000000
# 34             0.050000  0.000000     0.000000    0.000000
# 35             0.000000  0.000000     0.038462    0.000000
# 36             0.000000  0.000000     0.000000    0.000000
# 37             0.000000  0.000000     0.000000    0.000000
# 38             0.000000  0.033333     0.000000    0.000000
# 39             0.000000  0.000000     0.000000    0.000000
# 40             0.000000  0.000000     0.000000    0.000000
# 41             0.010000  0.000000     0.000000    0.000000
# 42             0.000000  0.000000     0.000000    0.000000
# 43             0.000000  0.000000     0.333333    0.000000
# 44             0.011628  0.000000     0.000000    0.000000
# 45             0.000000  0.000000     0.000000    0.043478
# 46             0.000000  0.000000     0.000000    0.000000
# 47             0.000000  0.000000     0.000000    0.000000
# 48             0.000000  0.000000     0.000000    0.000000
# 49             0.000000  0.019608     0.000000    0.000000
# 50             0.000000  0.023256     0.000000    0.000000
#
#     Arts & Crafts Store  Asian Restaurant  ...  Vegetarian / Vegan Restaurant  \
# 0              0.000000          0.024390  ...                       0.000000
# 1              0.000000          0.050000  ...                       0.016667
# 2              0.000000          0.045455  ...                       0.000000
# 3              0.000000          0.097222  ...                       0.000000
# 4              0.000000          0.000000  ...                       0.052632
# 5              0.000000          0.086957  ...                       0.000000
# 6              0.000000          0.065217  ...                       0.000000
# 7              0.000000          0.000000  ...                       0.000000
# 8              0.000000          0.000000  ...                       0.000000
# 9              0.000000          0.000000  ...                       0.000000
# 10             0.000000          0.000000  ...                       0.000000
# 11             0.000000          0.050000  ...                       0.000000
# 12             0.015385          0.046154  ...                       0.030769
# 13             0.000000          0.000000  ...                       0.000000
# 14             0.000000          0.064516  ...                       0.096774
# 15             0.000000          0.028571  ...                       0.000000
# 16             0.000000          0.013889  ...                       0.013889
# 17             0.000000          0.109375  ...                       0.000000
# 18             0.000000          0.000000  ...                       0.000000
# 19             0.000000          0.000000  ...                       0.000000
# 20             0.000000          1.000000  ...                       0.000000
# 21             0.000000          0.000000  ...                       0.000000
# 22             0.000000          0.000000  ...                       0.000000
# 23             0.000000          0.000000  ...                       0.000000
# 24             0.000000          0.027778  ...                       0.000000
# 25             0.000000          0.035714  ...                       0.000000
# 26             0.000000          0.063492  ...                       0.015873
# 27             0.000000          0.030000  ...                       0.000000
# 28             0.000000          0.000000  ...                       0.000000
# 29             0.000000          0.032258  ...                       0.000000
# 30             0.000000          0.064103  ...                       0.025641
# 31             0.000000          0.000000  ...                       0.000000
# 32             0.000000          0.025000  ...                       0.000000
# 33             0.000000          0.000000  ...                       0.062500
# 34             0.000000          0.050000  ...                       0.000000
# 35             0.000000          0.000000  ...                       0.192308
# 36             0.000000          0.000000  ...                       0.000000
# 37             0.000000          0.086957  ...                       0.000000
# 38             0.000000          0.033333  ...                       0.000000
# 39             0.000000          0.026316  ...                       0.000000
# 40             0.000000          0.000000  ...                       0.000000
# 41             0.000000          0.000000  ...                       0.030000
# 42             0.000000          0.000000  ...                       0.000000
# 43             0.000000          0.000000  ...                       0.000000
# 44             0.000000          0.011628  ...                       0.000000
# 45             0.000000          0.000000  ...                       0.000000
# 46             0.000000          0.042553  ...                       0.021277
# 47             0.000000          0.000000  ...                       0.000000
# 48             0.000000          0.000000  ...                       0.000000
# 49             0.000000          0.019608  ...                       0.000000
# 50             0.000000          0.000000  ...                       0.023256
#
#     Video Game Store  Vietnamese Restaurant  Waterfront  Whisky Bar  \
# 0           0.000000               0.000000    0.000000    0.000000
# 1           0.000000               0.000000    0.000000    0.000000
# 2           0.000000               0.000000    0.000000    0.000000
# 3           0.000000               0.000000    0.000000    0.000000
# 4           0.000000               0.000000    0.000000    0.000000
# 5           0.000000               0.000000    0.000000    0.000000
# 6           0.000000               0.000000    0.000000    0.000000
# 7           0.000000               0.000000    0.000000    0.000000
# 8           0.000000               0.000000    0.000000    0.000000
# 9           0.000000               0.000000    0.000000    0.000000
# 10          0.000000               0.000000    0.000000    0.000000
# 11          0.000000               0.000000    0.000000    0.000000
# 12          0.015385               0.000000    0.000000    0.000000
# 13          0.000000               0.000000    0.036364    0.000000
# 14          0.000000               0.000000    0.000000    0.000000
# 15          0.000000               0.000000    0.000000    0.000000
# 16          0.000000               0.000000    0.000000    0.000000
# 17          0.000000               0.000000    0.000000    0.000000
# 18          0.000000               0.000000    0.000000    0.000000
# 19          0.000000               0.000000    0.000000    0.000000
# 20          0.000000               0.000000    0.000000    0.000000
# 21          0.000000               0.000000    0.000000    0.000000
# 22          0.000000               0.000000    0.000000    0.000000
# 23          0.000000               0.000000    0.000000    0.000000
# 24          0.000000               0.000000    0.000000    0.027778
# 25          0.000000               0.000000    0.000000    0.000000
# 26          0.000000               0.015873    0.000000    0.000000
# 27          0.000000               0.000000    0.000000    0.000000
# 28          0.000000               0.000000    0.000000    0.000000
# 29          0.000000               0.000000    0.000000    0.000000
# 30          0.000000               0.012821    0.000000    0.000000
# 31          0.000000               0.000000    0.000000    0.000000
# 32          0.000000               0.025000    0.000000    0.000000
# 33          0.000000               0.000000    0.000000    0.000000
# 34          0.000000               0.000000    0.000000    0.000000
# 35          0.000000               0.000000    0.000000    0.000000
# 36          0.000000               0.000000    0.000000    0.000000
# 37          0.000000               0.000000    0.000000    0.000000
# 38          0.000000               0.000000    0.000000    0.000000
# 39          0.000000               0.000000    0.000000    0.000000
# 40          0.000000               0.000000    0.000000    0.000000
# 41          0.000000               0.020000    0.010000    0.000000
# 42          0.000000               0.000000    0.000000    0.000000
# 43          0.000000               0.000000    0.000000    0.000000
# 44          0.000000               0.000000    0.000000    0.000000
# 45          0.000000               0.000000    0.000000    0.000000
# 46          0.000000               0.000000    0.000000    0.000000
# 47          0.000000               0.000000    0.000000    0.000000
# 48          0.000000               0.000000    0.000000    0.000000
# 49          0.000000               0.000000    0.000000    0.000000
# 50          0.023256               0.000000    0.000000    0.000000
#
#     Wine Shop  Wings Joint  Women's Store  Yoga Studio  Zoo Exhibit
# 0        0.00     0.000000       0.000000     0.000000     0.000000
# 1        0.00     0.016667       0.000000     0.000000     0.000000
# 2        0.00     0.000000       0.000000     0.000000     0.000000
# 3        0.00     0.013889       0.000000     0.000000     0.000000
# 4        0.00     0.000000       0.000000     0.000000     0.000000
# 5        0.00     0.000000       0.000000     0.000000     0.000000
# 6        0.00     0.021739       0.000000     0.000000     0.000000
# 7        0.00     0.000000       0.000000     0.000000     0.000000
# 8        0.00     0.000000       0.000000     0.000000     0.000000
# 9        0.00     0.000000       0.000000     0.000000     0.000000
# 10       0.00     0.000000       0.000000     0.000000     0.000000
# 11       0.00     0.000000       0.000000     0.000000     0.000000
# 12       0.00     0.000000       0.000000     0.000000     0.000000
# 13       0.00     0.000000       0.000000     0.018182     0.000000
# 14       0.00     0.032258       0.000000     0.000000     0.000000
# 15       0.00     0.000000       0.000000     0.000000     0.000000
# 16       0.00     0.000000       0.000000     0.000000     0.000000
# 17       0.00     0.015625       0.000000     0.000000     0.000000
# 18       0.00     0.000000       0.000000     0.000000     0.000000
# 19       0.00     0.000000       0.000000     0.000000     0.333333
# 20       0.00     0.000000       0.000000     0.000000     0.000000
# 21       0.00     0.000000       0.000000     0.000000     0.000000
# 22       0.00     0.000000       0.000000     0.000000     0.000000
# 23       0.00     0.000000       0.000000     0.027027     0.000000
# 24       0.00     0.000000       0.000000     0.027778     0.000000
# 25       0.00     0.000000       0.000000     0.000000     0.000000
# 26       0.00     0.000000       0.000000     0.000000     0.000000
# 27       0.00     0.000000       0.000000     0.010000     0.000000
# 28       0.00     0.000000       0.000000     0.000000     0.000000
# 29       0.00     0.000000       0.000000     0.000000     0.000000
# 30       0.00     0.000000       0.000000     0.000000     0.000000
# 31       0.00     0.000000       0.000000     0.000000     0.000000
# 32       0.00     0.000000       0.025000     0.000000     0.000000
# 33       0.00     0.000000       0.000000     0.000000     0.000000
# 34       0.00     0.000000       0.000000     0.000000     0.000000
# 35       0.00     0.000000       0.000000     0.000000     0.000000
# 36       0.00     0.000000       0.000000     0.000000     0.000000
# 37       0.00     0.043478       0.000000     0.000000     0.000000
# 38       0.00     0.000000       0.033333     0.000000     0.000000
# 39       0.00     0.000000       0.000000     0.000000     0.000000
# 40       0.00     0.000000       0.000000     0.000000     0.000000
# 41       0.01     0.010000       0.000000     0.010000     0.000000
# 42       0.00     0.000000       0.000000     0.000000     0.000000
# 43       0.00     0.000000       0.000000     0.000000     0.000000
# 44       0.00     0.000000       0.000000     0.000000     0.000000
# 45       0.00     0.000000       0.000000     0.000000     0.000000
# 46       0.00     0.000000       0.000000     0.000000     0.000000
# 47       0.00     0.000000       0.000000     0.000000     0.000000
# 48       0.00     0.000000       0.000000     0.000000     0.000000
# 49       0.00     0.000000       0.000000     0.000000     0.000000
# 50       0.00     0.000000       0.000000     0.000000     0.000000
#
# [51 rows x 217 columns]

# %% [markdown]
# We can look at the top five most common venues for each neighborhood.

# %%
num_top_venues = 5

for hood in singapore_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = singapore_grouped[singapore_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Ang Mo Kio----
#              venue  freq
# 0      Coffee Shop  0.10
# 1       Food Court  0.07
# 2     Dessert Shop  0.07
# 3  Bubble Tea Shop  0.07
# 4      Supermarket  0.05
#
#
# ----Bedok----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Chinese Restaurant  0.05
# 2      Sandwich Place  0.05
# 3    Asian Restaurant  0.05
# 4        Noodle House  0.05
#
#
# ----Bishan----
#              venue  freq
# 0      Coffee Shop  0.09
# 1       Food Court  0.09
# 2  Bubble Tea Shop  0.07
# 3   Ice Cream Shop  0.07
# 4             Café  0.05
#
#
# ----Boon Lay----
#                   venue  freq
# 0   Japanese Restaurant  0.11
# 1      Asian Restaurant  0.10
# 2  Fast Food Restaurant  0.07
# 3    Chinese Restaurant  0.06
# 4          Dessert Shop  0.06
#
#
# ----Bukit Batok----
#                 venue  freq
# 0         Coffee Shop  0.21
# 1  Chinese Restaurant  0.11
# 2          Food Court  0.11
# 3      Sandwich Place  0.05
# 4       Shopping Mall  0.05
#
#
# ----Bukit Merah----
#                 venue  freq
# 0  Chinese Restaurant  0.13
# 1          Food Court  0.09
# 2                Café  0.09
# 3    Asian Restaurant  0.09
# 4        Dessert Shop  0.04
#
#
# ----Bukit Panjang----
#                   venue  freq
# 0  Fast Food Restaurant  0.09
# 1      Sushi Restaurant  0.07
# 2      Asian Restaurant  0.07
# 3           Bus Station  0.07
# 4           Supermarket  0.04
#
#
# ----Bukit Timah----
#                    venue  freq
# 0                  Trail  0.64
# 1         Scenic Lookout  0.18
# 2              Rest Area  0.09
# 3                   Hill  0.09
# 4  Performing Arts Venue  0.00
#
#
# ----Central Water Catchment----
#                    venue  freq
# 0              Reservoir  0.67
# 1       Business Service  0.33
# 2  Performing Arts Venue  0.00
# 3           Noodle House  0.00
# 4                 Office  0.00
#
#
# ----Changi----
#         venue  freq
# 0     Airport  0.33
# 1   Rest Area  0.17
# 2   Bookstore  0.17
# 3       Hotel  0.17
# 4  Food Court  0.17
#
#
# ----Changi Bay----
#             venue  freq
# 0   Boat or Ferry  0.33
# 1     Pizza Place  0.17
# 2      Smoke Shop  0.17
# 3  History Museum  0.17
# 4        Gym Pool  0.17
#
#
# ----Choa Chu Kang----
#                   venue  freq
# 0           Coffee Shop  0.10
# 1            Food Court  0.10
# 2           Bus Station  0.10
# 3  Fast Food Restaurant  0.10
# 4                Bakery  0.05
#
#
# ----Clementi----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1          Food Court  0.08
# 2  Chinese Restaurant  0.05
# 3         Bus Station  0.05
# 4        Dessert Shop  0.05
#
#
# ----Downtown Core----
#                    venue  freq
# 0           Concert Hall  0.05
# 1   Gym / Fitness Center  0.05
# 2             Waterfront  0.04
# 3  Performing Arts Venue  0.04
# 4           Cocktail Bar  0.04
#
#
# ----Geylang----
#                            venue  freq
# 0             Chinese Restaurant  0.23
# 1                   Noodle House  0.10
# 2                     Food Court  0.10
# 3  Vegetarian / Vegan Restaurant  0.10
# 4                  Grocery Store  0.06
#
#
# ----Hougang----
#                   venue  freq
# 0            Food Court  0.11
# 1  Fast Food Restaurant  0.09
# 2    Chinese Restaurant  0.09
# 3           Supermarket  0.06
# 4           Coffee Shop  0.06
#
#
# ----Jurong East----
#                  venue  freq
# 0           Food Court  0.10
# 1                 Café  0.07
# 2          Coffee Shop  0.07
# 3   Chinese Restaurant  0.07
# 4  Japanese Restaurant  0.07
#
#
# ----Jurong West----
#                   venue  freq
# 0   Japanese Restaurant  0.12
# 1      Asian Restaurant  0.11
# 2  Fast Food Restaurant  0.08
# 3    Chinese Restaurant  0.06
# 4           Coffee Shop  0.05
#
#
# ----Kallang----
#                    venue  freq
# 0             Restaurant  0.25
# 1            Supermarket  0.25
# 2            Coffee Shop  0.25
# 3                 Hostel  0.25
# 4  Performing Arts Venue  0.00
#
#
# ----Lim Chu Kang----
#                    venue  freq
# 0            Zoo Exhibit  0.33
# 1              Gift Shop  0.33
# 2                   Farm  0.33
# 3  Performing Arts Venue  0.00
# 4           Noodle House  0.00
#
#
# ----Mandai----
#               venue  freq
# 0  Asian Restaurant   1.0
# 1               ATM   0.0
# 2         Pet Store   0.0
# 3      Noodle House   0.0
# 4            Office   0.0
#
#
# ----Marina East----
#                    venue  freq
# 0                   Park  0.50
# 1              Reservoir  0.25
# 2                   Café  0.25
# 3  Performing Arts Venue  0.00
# 4           Noodle House  0.00
#
#
# ----Marina South----
#                     venue  freq
# 0                  Garden   0.4
# 1                   Hotel   0.2
# 2            Skating Rink   0.2
# 3                    Park   0.2
# 4  Peking Duck Restaurant   0.0
#
#
# ----Marine Parade----
#                  venue  freq
# 0                Hotel  0.11
# 1  Japanese Restaurant  0.08
# 2            Multiplex  0.08
# 3       Massage Studio  0.08
# 4          Supermarket  0.05
#
#
# ----Museum----
#                  venue  freq
# 0                Hotel  0.11
# 1  Japanese Restaurant  0.08
# 2         Dessert Shop  0.08
# 3      Bubble Tea Shop  0.06
# 4       Cosmetics Shop  0.06
#
#
# ----Newton----
#                 venue  freq
# 0  Chinese Restaurant  0.21
# 1  Seafood Restaurant  0.14
# 2           Hotel Bar  0.07
# 3  Italian Restaurant  0.07
# 4          Food Court  0.04
#
#
# ----Novena----
#               venue  freq
# 0       Coffee Shop  0.10
# 1              Café  0.08
# 2  Asian Restaurant  0.06
# 3             Hotel  0.06
# 4  Ramen Restaurant  0.05
#
#
# ----Orchard----
#                  venue  freq
# 0             Boutique  0.09
# 1  Japanese Restaurant  0.08
# 2               Bakery  0.06
# 3     Sushi Restaurant  0.05
# 4                Hotel  0.05
#
#
# ----Outram----
#                 venue  freq
# 0              Bakery  0.17
# 1  Dim Sum Restaurant  0.08
# 2               Hotel  0.08
# 3       Grocery Store  0.08
# 4          Nail Salon  0.08
#
#
# ----Pasir Ris----
#                   venue  freq
# 0            Food Court  0.10
# 1                 Diner  0.06
# 2    Italian Restaurant  0.06
# 3  Fast Food Restaurant  0.06
# 4        Sandwich Place  0.06
#
#
# ----Paya Lebar----
#                   venue  freq
# 0         Shopping Mall  0.08
# 1      Asian Restaurant  0.06
# 2  Fast Food Restaurant  0.06
# 3            Food Court  0.05
# 4           Supermarket  0.04
#
#
# ----Pioneer----
#                   venue  freq
# 0           Bus Station  0.19
# 1               Stadium  0.12
# 2         Shopping Mall  0.06
# 3  Fast Food Restaurant  0.06
# 4           Supermarket  0.06
#
#
# ----Punggol----
#                   venue  freq
# 0   Japanese Restaurant  0.08
# 1    Chinese Restaurant  0.08
# 2  Fast Food Restaurant  0.05
# 3    Light Rail Station  0.05
# 4           Supermarket  0.05
#
#
# ----Queenstown----
#                 venue  freq
# 0          Food Court  0.19
# 1        Noodle House  0.12
# 2  Chinese Restaurant  0.12
# 3  Italian Restaurant  0.06
# 4       Train Station  0.06
#
#
# ----River Valley----
#                   venue  freq
# 0                Bakery  0.15
# 1                  Café  0.10
# 2            Steakhouse  0.05
# 3  Fast Food Restaurant  0.05
# 4            Shoe Store  0.05
#
#
# ----Rochor----
#                            venue  freq
# 0              Indian Restaurant  0.35
# 1  Vegetarian / Vegan Restaurant  0.19
# 2             Chinese Restaurant  0.08
# 3                      BBQ Joint  0.04
# 4                     Restaurant  0.04
#
#
# ----Seletar----
#              venue  freq
# 0      Snack Place  0.25
# 1       Food Court  0.25
# 2             Café  0.25
# 3  Harbor / Marina  0.25
# 4              ATM  0.00
#
#
# ----Sembawang----
#                   venue  freq
# 0  Fast Food Restaurant  0.09
# 1      Asian Restaurant  0.09
# 2         Shopping Mall  0.09
# 3           Coffee Shop  0.09
# 4   Sporting Goods Shop  0.04
#
#
# ----Sengkang----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1            Food Court  0.10
# 2           Coffee Shop  0.07
# 3      Sushi Restaurant  0.07
# 4        Sandwich Place  0.03
#
#
# ----Serangoon----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1   Chinese Restaurant  0.08
# 2  Japanese Restaurant  0.05
# 3         Noodle House  0.05
# 4       Ice Cream Shop  0.05
#
#
# ----Simpang----
#                    venue  freq
# 0               Platform   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3              Nightclub   0.0
# 4           Noodle House   0.0
#
#
# ----Singapore River----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1                Hotel  0.07
# 2            Nightclub  0.06
# 3      Thai Restaurant  0.04
# 4                 Café  0.03
#
#
# ----Straits View----
#                    venue  freq
# 0          Boat or Ferry   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3           Noodle House   0.0
# 4                 Office   0.0
#
#
# ----Sungei Kadut----
#                    venue  freq
# 0                 Office  0.33
# 1            Art Gallery  0.33
# 2            Bus Station  0.33
# 3                    ATM  0.00
# 4  Performing Arts Venue  0.00
#
#
# ----Tampines----
#            venue  freq
# 0           Café  0.07
# 1         Bakery  0.06
# 2    Coffee Shop  0.05
# 3            Gym  0.03
# 4  Shopping Mall  0.03
#
#
# ----Tanglin----
#                venue  freq
# 0    Thai Restaurant  0.09
# 1  French Restaurant  0.09
# 2             Garden  0.09
# 3               Park  0.09
# 4             Bakery  0.09
#
#
# ----Toa Payoh----
#                 venue  freq
# 0        Noodle House  0.13
# 1  Chinese Restaurant  0.13
# 2          Food Court  0.09
# 3         Coffee Shop  0.06
# 4         Snack Place  0.06
#
#
# ----Tuas----
#           venue  freq
# 0  Concert Hall  0.33
# 1   Coffee Shop  0.33
# 2      Bus Stop  0.33
# 3           ATM  0.00
# 4      Pharmacy  0.00
#
#
# ----Western Water Catchment----
#                    venue  freq
# 0              Gun Range   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3           Noodle House   0.0
# 4                 Office   0.0
#
#
# ----Woodlands----
#                  venue  freq
# 0  Japanese Restaurant  0.08
# 1                 Café  0.06
# 2          Coffee Shop  0.06
# 3   Frozen Yogurt Shop  0.04
# 4   Chinese Restaurant  0.04
#
#
# ----Yishun----
#                   venue  freq
# 0            Food Court  0.12
# 1    Chinese Restaurant  0.07
# 2   Fried Chicken Joint  0.05
# 3           Supermarket  0.05
# 4  Fast Food Restaurant  0.05

# %% [markdown]
# This information can also be put into a dataframe showing the top ten most common venues for each Singaporean neighborhood.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = singapore_grouped['Neighborhood']

for ind in np.arange(singapore_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(singapore_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted
# Out:
#                Neighborhood 1st Most Common Venue  \
# 0                Ang Mo Kio           Coffee Shop
# 1                     Bedok           Coffee Shop
# 2                    Bishan            Food Court
# 3                  Boon Lay   Japanese Restaurant
# 4               Bukit Batok           Coffee Shop
# 5               Bukit Merah    Chinese Restaurant
# 6             Bukit Panjang  Fast Food Restaurant
# 7               Bukit Timah                 Trail
# 8   Central Water Catchment             Reservoir
# 9                    Changi               Airport
# 10               Changi Bay         Boat or Ferry
# 11            Choa Chu Kang           Coffee Shop
# 12                 Clementi           Coffee Shop
# 13            Downtown Core          Concert Hall
# 14                  Geylang    Chinese Restaurant
# 15                  Hougang            Food Court
# 16              Jurong East            Food Court
# 17              Jurong West   Japanese Restaurant
# 18                  Kallang            Restaurant
# 19             Lim Chu Kang           Zoo Exhibit
# 20                   Mandai      Asian Restaurant
# 21              Marina East                  Park
# 22             Marina South                Garden
# 23            Marine Parade                 Hotel
# 24                   Museum                 Hotel
# 25                   Newton    Chinese Restaurant
# 26                   Novena           Coffee Shop
# 27                  Orchard              Boutique
# 28                   Outram                Bakery
# 29                Pasir Ris            Food Court
# 30               Paya Lebar         Shopping Mall
# 31                  Pioneer           Bus Station
# 32                  Punggol    Chinese Restaurant
# 33               Queenstown            Food Court
# 34             River Valley                Bakery
# 35                   Rochor     Indian Restaurant
# 36                  Seletar            Food Court
# 37                Sembawang           Coffee Shop
# 38                 Sengkang  Fast Food Restaurant
# 39                Serangoon           Coffee Shop
# 40                  Simpang              Platform
# 41          Singapore River                 Hotel
# 42             Straits View         Boat or Ferry
# 43             Sungei Kadut                Office
# 44                 Tampines                  Café
# 45                  Tanglin                  Park
# 46                Toa Payoh    Chinese Restaurant
# 47                     Tuas          Concert Hall
# 48  Western Water Catchment             Gun Range
# 49                Woodlands   Japanese Restaurant
# 50                   Yishun            Food Court
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0                    Dessert Shop       Bubble Tea Shop
# 1                Asian Restaurant          Noodle House
# 2                     Coffee Shop       Bubble Tea Shop
# 3                Asian Restaurant  Fast Food Restaurant
# 4              Chinese Restaurant            Food Court
# 5                      Food Court                  Café
# 6                Asian Restaurant           Bus Station
# 7                  Scenic Lookout             Rest Area
# 8                Business Service        Farmers Market
# 9                       Rest Area                 Hotel
# 10                    Pizza Place        History Museum
# 11           Fast Food Restaurant           Bus Station
# 12                     Food Court          Dessert Shop
# 13           Gym / Fitness Center                Lounge
# 14                   Noodle House            Food Court
# 15             Chinese Restaurant  Fast Food Restaurant
# 16                           Café           Coffee Shop
# 17               Asian Restaurant  Fast Food Restaurant
# 18                         Hostel           Coffee Shop
# 19                      Gift Shop                  Farm
# 20                    Zoo Exhibit        Farmers Market
# 21                      Reservoir                  Café
# 22                           Park                 Hotel
# 23                      Multiplex        Massage Studio
# 24                   Dessert Shop   Japanese Restaurant
# 25             Seafood Restaurant    Italian Restaurant
# 26                           Café                 Hotel
# 27            Japanese Restaurant                Bakery
# 28             Seafood Restaurant             Gastropub
# 29             Italian Restaurant                 Diner
# 30           Fast Food Restaurant      Asian Restaurant
# 31                        Stadium                  Pool
# 32            Japanese Restaurant           Supermarket
# 33                   Noodle House    Chinese Restaurant
# 34                           Café        Clothing Store
# 35  Vegetarian / Vegan Restaurant    Chinese Restaurant
# 36                    Snack Place       Harbor / Marina
# 37           Fast Food Restaurant         Shopping Mall
# 38                     Food Court      Sushi Restaurant
# 39             Chinese Restaurant   Japanese Restaurant
# 40                    Zoo Exhibit                  Farm
# 41            Japanese Restaurant             Nightclub
# 42                    Zoo Exhibit  Fast Food Restaurant
# 43                    Art Gallery           Bus Station
# 44                         Bakery           Coffee Shop
# 45              French Restaurant                Garden
# 46                   Noodle House            Food Court
# 47                    Coffee Shop              Bus Stop
# 48                    Zoo Exhibit        Farmers Market
# 49                    Coffee Shop                  Café
# 50             Chinese Restaurant     Hainan Restaurant
#
#             4th Most Common Venue      5th Most Common Venue  \
# 0                      Food Court        Japanese Restaurant
# 1             Japanese Restaurant                 Food Court
# 2                  Ice Cream Shop         Chinese Restaurant
# 3                    Dessert Shop         Chinese Restaurant
# 4              Italian Restaurant           Malay Restaurant
# 5                Asian Restaurant               Dessert Shop
# 6                Sushi Restaurant              Shopping Mall
# 7                            Hill                Zoo Exhibit
# 8              Frozen Yogurt Shop        Fried Chicken Joint
# 9                       Bookstore                 Food Court
# 10                     Smoke Shop                   Gym Pool
# 11                     Food Court         Italian Restaurant
# 12                    Bus Station       Fast Food Restaurant
# 13                          Hotel                  Hotel Bar
# 14  Vegetarian / Vegan Restaurant           Asian Restaurant
# 15                           Café                Coffee Shop
# 16            Japanese Restaurant         Chinese Restaurant
# 17             Chinese Restaurant               Dessert Shop
# 18                    Supermarket                Zoo Exhibit
# 19               Department Store               Dessert Shop
# 20         Furniture / Home Store         Frozen Yogurt Shop
# 21            Fried Chicken Joint          French Restaurant
# 22                   Skating Rink                Zoo Exhibit
# 23            Japanese Restaurant          Indian Restaurant
# 24                 Cosmetics Shop            Bubble Tea Shop
# 25                      Hotel Bar            Thai Restaurant
# 26               Asian Restaurant         Italian Restaurant
# 27               Sushi Restaurant                      Hotel
# 28                           Café              Grocery Store
# 29                 Sandwich Place          Convenience Store
# 30                     Food Court               Noodle House
# 31           Gym / Fitness Center                Flower Shop
# 32             Light Rail Station            Bubble Tea Shop
# 33             Italian Restaurant              Train Station
# 34                  Grocery Store       Fast Food Restaurant
# 35                           Café  Middle Eastern Restaurant
# 36                           Café                Zoo Exhibit
# 37               Asian Restaurant        Government Building
# 38                    Coffee Shop         Chinese Restaurant
# 39           Fast Food Restaurant             Clothing Store
# 40             Frozen Yogurt Shop        Fried Chicken Joint
# 41                Thai Restaurant         Italian Restaurant
# 42         Furniture / Home Store         Frozen Yogurt Shop
# 43                    Zoo Exhibit       Fast Food Restaurant
# 44               Sushi Restaurant              Shopping Mall
# 45                Thai Restaurant                     Bakery
# 46                    Snack Place                Coffee Shop
# 47                    Zoo Exhibit       Fast Food Restaurant
# 48             Frozen Yogurt Shop        Fried Chicken Joint
# 49             Frozen Yogurt Shop                Supermarket
# 50                    Coffee Shop        Fried Chicken Joint
#
#     6th Most Common Venue       7th Most Common Venue  \
# 0             Supermarket                Noodle House
# 1          Sandwich Place          Chinese Restaurant
# 2     Japanese Restaurant                        Café
# 3              Playground                 Coffee Shop
# 4          Sandwich Place        Fast Food Restaurant
# 5              Club House                        Pool
# 6   Indonesian Restaurant                  Restaurant
# 7             Event Space           French Restaurant
# 8       French Restaurant                  Food Stand
# 9             Zoo Exhibit              Farmers Market
# 10            Zoo Exhibit              Farmers Market
# 11                 Bakery                  Playground
# 12     Chinese Restaurant            Asian Restaurant
# 13            Coffee Shop                  Waterfront
# 14     Dim Sum Restaurant               Grocery Store
# 15            Supermarket                 Pizza Place
# 16          Shopping Mall      Furniture / Home Store
# 17            Coffee Shop                        Park
# 18                   Farm         Fried Chicken Joint
# 19     Frozen Yogurt Shop         Fried Chicken Joint
# 20    Fried Chicken Joint           French Restaurant
# 21             Food Stand                  Food Court
# 22      French Restaurant                  Food Stand
# 23     Chinese Restaurant                 Supermarket
# 24          Movie Theater       General Entertainment
# 25                  Hotel         Japanese Restaurant
# 26     Chinese Restaurant            Ramen Restaurant
# 27     Chinese Restaurant               Shopping Mall
# 28         Farmers Market                  Nail Salon
# 29   Fast Food Restaurant             Other Nightlife
# 30            Coffee Shop          Chinese Restaurant
# 31               Bus Line                 Supermarket
# 32   Fast Food Restaurant              Sandwich Place
# 33                   Pool                     Stadium
# 34           Gourmet Shop                  Steakhouse
# 35              BBQ Joint                  Restaurant
# 36         Farmers Market         Fried Chicken Joint
# 37               Pharmacy                   Pet Store
# 38           Noodle House              Sandwich Place
# 39         Ice Cream Shop           Korean Restaurant
# 40      French Restaurant                  Food Stand
# 41                   Café                Noodle House
# 42    Fried Chicken Joint           French Restaurant
# 43     Frozen Yogurt Shop         Fried Chicken Joint
# 44                    Gym             Bubble Tea Shop
# 45                Brewery  Tourist Information Center
# 46             Steakhouse            Asian Restaurant
# 47     Frozen Yogurt Shop         Fried Chicken Joint
# 48      French Restaurant                  Food Stand
# 49      Electronics Store           Indian Restaurant
# 50   Fast Food Restaurant                 Supermarket
#
#             8th Most Common Venue  9th Most Common Venue  \
# 0            Fast Food Restaurant         Sandwich Place
# 1                    Dessert Shop            Supermarket
# 2                Asian Restaurant            Supermarket
# 3               Indian Restaurant            Karaoke Bar
# 4                            Café          Shopping Mall
# 5                       Cable Car               Mountain
# 6                     Supermarket            Coffee Shop
# 7                      Food Stand             Food Court
# 8                      Food Court            Flower Shop
# 9              Frozen Yogurt Shop    Fried Chicken Joint
# 10            Fried Chicken Joint      French Restaurant
# 11                 Sandwich Place                   Café
# 12             Dim Sum Restaurant         Sandwich Place
# 13                   Cocktail Bar  Performing Arts Venue
# 14           Cantonese Restaurant   Fast Food Restaurant
# 15                  Shopping Mall     Frozen Yogurt Shop
# 16                Bubble Tea Shop         Clothing Store
# 17              Indian Restaurant                   Café
# 18              French Restaurant             Food Stand
# 19                   Dance Studio      French Restaurant
# 20                     Food Stand             Food Court
# 21                    Flower Shop            Flea Market
# 22                     Food Court            Flower Shop
# 23              Recreation Center          Shopping Mall
# 24                    Gaming Cafe                    Spa
# 25           Gym / Fitness Center          Grocery Store
# 26              Hotpot Restaurant      Hainan Restaurant
# 27                 Cosmetics Shop  Indonesian Restaurant
# 28             Spanish Restaurant                  Hotel
# 29           Outdoor Supply Store                   Park
# 30            Fried Chicken Joint        Bubble Tea Shop
# 31                  Shopping Mall   Fast Food Restaurant
# 32                     Soup Place         Breakfast Spot
# 33                           Café     Seafood Restaurant
# 34            Fried Chicken Joint            Salad Place
# 35                    Art Gallery            Gaming Cafe
# 36              French Restaurant             Food Stand
# 37                           Park     Chinese Restaurant
# 38                           Café       Sculpture Garden
# 39                   Noodle House            Supermarket
# 40                     Food Court            Flower Shop
# 41  Vegetarian / Vegan Restaurant             Food Court
# 42                     Food Stand             Food Court
# 43              French Restaurant             Food Stand
# 44           Fast Food Restaurant     Chinese Restaurant
# 45             Seafood Restaurant                   Café
# 46                Thai Restaurant                   Café
# 47              French Restaurant             Food Stand
# 48                     Food Court            Flower Shop
# 49                 Clothing Store   Fast Food Restaurant
# 50                       Bus Line              Bookstore
#
#         10th Most Common Venue
# 0           Seafood Restaurant
# 1                 Burger Joint
# 2               Cosmetics Shop
# 3                         Park
# 4           Frozen Yogurt Shop
# 5                Bowling Alley
# 6                         Café
# 7                  Flower Shop
# 8                  Flea Market
# 9            French Restaurant
# 10                  Food Stand
# 11                Noodle House
# 12               Shopping Mall
# 13                 Salad Place
# 14            Basketball Court
# 15           Fish & Chips Shop
# 16                   Multiplex
# 17           Electronics Store
# 18                  Food Court
# 19                  Food Stand
# 20                 Flower Shop
# 21           Fish & Chips Shop
# 22                 Flea Market
# 23                        Café
# 24           French Restaurant
# 25               Movie Theater
# 26         Japanese Restaurant
# 27            Asian Restaurant
# 28                 Coffee Shop
# 29                    Pharmacy
# 30                 Supermarket
# 31            Basketball Court
# 32               Shopping Mall
# 33                         Spa
# 34                 Coffee Shop
# 35                       Hotel
# 36                 Flower Shop
# 37                    Bus Stop
# 38                Optical Shop
# 39                   Bookstore
# 40                 Flea Market
# 41                         Bar
# 42                 Flower Shop
# 43                  Food Court
# 44                 Supermarket
# 45  Modern European Restaurant
# 46             Bubble Tea Shop
# 47                  Food Court
# 48                 Flea Market
# 49          Chinese Restaurant
# 50      Furniture / Home Store

# %% [markdown]
# Next, we would like to rank the neighborhoods in terms of number of gyms.

# %%
singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()
# Out:
#        Neighborhood  0
# 0          Tampines  4
# 1   Singapore River  3
# 2     Downtown Core  3
# 3        Ang Mo Kio  2
# 4           Pioneer  2
# 5          Clementi  2
# 6           Hougang  1
# 7            Bishan  1
# 8          Boon Lay  1
# 9       Bukit Merah  1
# 10    Bukit Panjang  1
# 11        Woodlands  1
# 12      Jurong East  1
# 13           Museum  1
# 14           Newton  1
# 15           Novena  1
# 16        Pasir Ris  1
# 17         Sengkang  1
# 18      Jurong West  1

# %% [markdown]
# Let us look at the top six Singaporean neighborhoods with the most gyms.

# %%
neighborhoodsMostGyms = singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:6]          
for index,value in neighborhoodsMostGyms.iteritems():
    print(value)
# Out:
# Tampines
# Singapore River
# Downtown Core
# Ang Mo Kio
# Pioneer
# Clementi

# %% [markdown]
# Let us plot these neighborhoods on a map.

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
neighborhoodsMostGyms = singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:6]          
for index,value in neighborhoodsMostGyms.iteritems():
    neighborhood = value
    lat = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Latitude'].iloc[0]
    lng = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Longitude'].iloc[0]    
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_fce44c87c92d41beaace9caa13fa5735%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fce44c87c92d41beaace9caa13fa5735%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fce44c87c92d41beaace9caa13fa5735%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_fce44c87c92d41beaace9caa13fa5735%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Next, we can look at which neighborhoods have the most malls.

# %%
singapore_venues[singapore_venues["Venue Category"] == 'Shopping Mall']
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 24       Ang Mo Kio               1.370080              103.849523
# 65            Bedok               1.323976              103.930216
# 117          Bishan               1.350986              103.848255
# 152        Boon Lay               1.338550              103.705812
# 231     Bukit Batok               1.349057              103.749591
# 265   Bukit Panjang               1.377917              103.763095
# 272   Bukit Panjang               1.377917              103.763095
# 393        Clementi               1.315100              103.765231
# 398        Clementi               1.315100              103.765231
# 530         Hougang               1.370801              103.892544
# 550     Jurong East               1.333108              103.742294
# 553     Jurong East               1.333108              103.742294
# 591     Jurong East               1.333108              103.742294
# 616     Jurong West               1.339636              103.707339
# 701   Marine Parade               1.302689              103.907395
# 856         Orchard               1.303427              103.831342
# 903         Orchard               1.303427              103.831342
# 923         Orchard               1.303427              103.831342
# 924         Orchard               1.303427              103.831342
# 975       Pasir Ris               1.373031              103.949255
# 1009     Paya Lebar               1.317480              103.892353
# 1043     Paya Lebar               1.317480              103.892353
# 1053     Paya Lebar               1.317480              103.892353
# 1056     Paya Lebar               1.317480              103.892353
# 1064     Paya Lebar               1.317480              103.892353
# 1068     Paya Lebar               1.317480              103.892353
# 1086        Pioneer               1.337588              103.697410
# 1091        Punggol               1.405197              103.902350
# 1205      Sembawang               1.449093              103.820055
# 1218      Sembawang               1.449093              103.820055
# 1236       Sengkang               1.391924              103.895491
# 1272      Serangoon               1.349761              103.873684
# 1412       Tampines               1.354653              103.943571
# 1426       Tampines               1.354653              103.943571
# 1449       Tampines               1.354653              103.943571
# 1581      Woodlands               1.436897              103.786216
# 1584      Woodlands               1.436897              103.786216
# 1630         Yishun               1.429384              103.835028
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 24                        AMK Hub        1.369247       103.848525
# 65                     Bedok Mall        1.324984       103.929361
# 117    Junction 8 Shopping Centre        1.350534       103.848732
# 152                  Jurong Point        1.339121       103.706352
# 231                     West Mall        1.349910       103.749199
# 265                  Hillion Mall        1.378074       103.762670
# 272           Bukit Panjang Plaza        1.380137       103.764153
# 393                  321 Clementi        1.311964       103.765072
# 398             The Clementi Mall        1.315036       103.764909
# 530                  Hougang Mall        1.372702       103.893793
# 550                      Westgate        1.334225       103.742824
# 553                           Jem        1.333319       103.743117
# 591                         JCube        1.333413       103.740386
# 616                  Jurong Point        1.339121       103.706352
# 701                Parkway Parade        1.301715       103.905283
# 856                   ION Orchard        1.304444       103.831852
# 903              Takashimaya S.C.        1.302720       103.834909
# 923                   The Paragon        1.303526       103.835639
# 924                 Ngee Ann City        1.302546       103.834566
# 975   White Sands Shopping Centre        1.372433       103.949484
# 1009                     PLQ Mall        1.317364       103.892834
# 1043            Paya Lebar Square        1.318632       103.892627
# 1053                        KINEX        1.315006       103.894454
# 1056              SingPost Centre        1.318494       103.893450
# 1064       Tanjong Katong Complex        1.316248       103.894379
# 1068                   City Plaza        1.315059       103.893111
# 1086                 Pioneer Mall        1.341845       103.696986
# 1091               Waterway Point        1.405425       103.902411
# 1205                    Sun Plaza        1.448387       103.819750
# 1218               Sembawang Mart        1.453373       103.819636
# 1236                  Compass One        1.392350       103.895068
# 1272                          nex        1.350103       103.872764
# 1412                   Tampines 1        1.354077       103.945224
# 1426                Tampines Mall        1.352567       103.944896
# 1449               Century Square        1.352694       103.943953
# 1581               Causeway Point        1.435998       103.785959
# 1584       Woodlands Civic Centre        1.434946       103.786786
# 1630              Northpoint City        1.428847       103.836197
#
#      Venue Category
# 24    Shopping Mall
# 65    Shopping Mall
# 117   Shopping Mall
# 152   Shopping Mall
# 231   Shopping Mall
# 265   Shopping Mall
# 272   Shopping Mall
# 393   Shopping Mall
# 398   Shopping Mall
# 530   Shopping Mall
# 550   Shopping Mall
# 553   Shopping Mall
# 591   Shopping Mall
# 616   Shopping Mall
# 701   Shopping Mall
# 856   Shopping Mall
# 903   Shopping Mall
# 923   Shopping Mall
# 924   Shopping Mall
# 975   Shopping Mall
# 1009  Shopping Mall
# 1043  Shopping Mall
# 1053  Shopping Mall
# 1056  Shopping Mall
# 1064  Shopping Mall
# 1068  Shopping Mall
# 1086  Shopping Mall
# 1091  Shopping Mall
# 1205  Shopping Mall
# 1218  Shopping Mall
# 1236  Shopping Mall
# 1272  Shopping Mall
# 1412  Shopping Mall
# 1426  Shopping Mall
# 1449  Shopping Mall
# 1581  Shopping Mall
# 1584  Shopping Mall
# 1630  Shopping Mall

# %%
singapore_venues[singapore_venues["Venue Category"] == 'Shopping Mall'].value_counts(subset=['Neighborhood']).to_frame().reset_index()
# Out:
#      Neighborhood  0
# 0      Paya Lebar  6
# 1         Orchard  4
# 2        Tampines  3
# 3     Jurong East  3
# 4       Sembawang  2
# 5   Bukit Panjang  2
# 6       Woodlands  2
# 7        Clementi  2
# 8          Yishun  1
# 9         Hougang  1
# 10          Bedok  1
# 11         Bishan  1
# 12       Boon Lay  1
# 13    Bukit Batok  1
# 14  Marine Parade  1
# 15    Jurong West  1
# 16      Pasir Ris  1
# 17        Pioneer  1
# 18        Punggol  1
# 19       Sengkang  1
# 20      Serangoon  1
# 21     Ang Mo Kio  1

# %%
neighborhoodsMostMalls = singapore_venues[singapore_venues["Venue Category"] == 'Shopping Mall'].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:7]                      
neighborhoodsMostMalls
# Out:
# 0       Paya Lebar
# 1          Orchard
# 2         Tampines
# 3      Jurong East
# 4        Sembawang
# 5    Bukit Panjang
# 6        Woodlands
# Name: Neighborhood, dtype: object

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
for index,value in neighborhoodsMostMalls.iteritems():
    neighborhood = value
    lat = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Latitude'].iloc[0]
    lng = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Longitude'].iloc[0]    
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_1f687cdaf91d4cea83b525958327a64b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1f687cdaf91d4cea83b525958327a64b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1f687cdaf91d4cea83b525958327a64b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_1f687cdaf91d4cea83b525958327a64b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Lastly, let us see which neighborhoods have the most coffee shops.

# %%
singapore_venues[singapore_venues["Venue Category"] == 'Coffee Shop'].value_counts(subset=['Neighborhood']).to_frame().reset_index()
# Out:
#        Neighborhood  0
# 0          Clementi  6
# 1            Novena  6
# 2       Jurong East  5
# 3        Ang Mo Kio  4
# 4             Bedok  4
# 5            Bishan  4
# 6          Tampines  4
# 7       Bukit Batok  4
# 8        Paya Lebar  3
# 9          Boon Lay  3
# 10      Jurong West  3
# 11        Woodlands  3
# 12          Orchard  3
# 13        Toa Payoh  3
# 14        Serangoon  3
# 15    Downtown Core  2
# 16          Hougang  2
# 17    Bukit Panjang  2
# 18    Choa Chu Kang  2
# 19         Sengkang  2
# 20           Yishun  2
# 21        Sembawang  2
# 22           Outram  1
# 23     River Valley  1
# 24          Kallang  1
# 25    Marine Parade  1
# 26       Queenstown  1
# 27  Singapore River  1
# 28          Punggol  1
# 29             Tuas  1
# 30        Pasir Ris  1

# %% [markdown]
# The top eight neighborhoods with the most coffee shops are listed below:

# %%
neighborhoodsMostCoffeeShops = singapore_venues[singapore_venues["Venue Category"] == 'Coffee Shop'].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:8]        
neighborhoodsMostCoffeeShops
# Out:
# 0       Clementi
# 1         Novena
# 2    Jurong East
# 3     Ang Mo Kio
# 4          Bedok
# 5         Bishan
# 6       Tampines
# 7    Bukit Batok
# Name: Neighborhood, dtype: object

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
for index,value in neighborhoodsMostCoffeeShops.iteritems():
    neighborhood = value
    lat = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Latitude'].iloc[0]
    lng = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Longitude'].iloc[0]    
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_b70994ef4c364d3b81630fd12ada3240%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b70994ef4c364d3b81630fd12ada3240%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b70994ef4c364d3b81630fd12ada3240%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_b70994ef4c364d3b81630fd12ada3240%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

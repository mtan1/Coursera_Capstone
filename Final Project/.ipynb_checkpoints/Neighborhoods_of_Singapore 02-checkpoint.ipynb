# %% [markdown]
# <font size="4">Creating dataframe of Singaporean districts and their coordinates.</font>

# %% [markdown]
# Let us first create a dataframe that contains the districts of Singapore and their coordinates by scraping the data from Wikipedia.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import geocoder # import geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
import json # library to handle JSON files
import numpy as np

url = "https://en.wikipedia.org/wiki/Planning_Areas_of_Singapore" #Url of Wikipedia page with Toronto neighborhoods and postal codes
data  = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")
tables = soup.find_all('table') #Find tables in the html
planningArea_data = pd.DataFrame(columns=["Planning Area","Latitude","Longitude"])
for row in tables[2].tbody.find_all("tr"):    
    col =row.td
    if col != None:
        planningArea = col.text.strip()
        geolocator = Nominatim(user_agent="sg_explorer")
        address = '{}, SG'.format(planningArea)
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        planningArea_data = planningArea_data.append({"Planning Area": planningArea,"Latitude": latitude,"Longitude" : longitude}, ignore_index=True)

# %% [markdown]
# Create a map of Singapore and show all the districts.

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
for lat, lng, neighborhood in zip(planningArea_data["Latitude"], planningArea_data["Longitude"], planningArea_data["Planning Area"]):
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_678e3fcddc714e23a2f75cc21401407f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_678e3fcddc714e23a2f75cc21401407f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_678e3fcddc714e23a2f75cc21401407f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_678e3fcddc714e23a2f75cc21401407f%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Define Foursquare credentials

# %%
CLIENT_ID = 'IRKFWJXIIWOMSCV1EBIGSM4C1ODUR1V1WB4XXDKUARYY4WXH' # your Foursquare ID
CLIENT_SECRET = '0B4YEAJQNMY3Y02RUNAWKD0VEX2CD4Q25UH4WPALOSHHNDUU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# <font size="4">Exploring the first district in the planningArea_data Dataframe</font>

# %%
print("The first district in the dataframe is {}.".format(planningArea_data.loc[0, "Planning Area"]))
# Out:
# The first district in the dataframe is Ang Mo Kio.

# %%
neighborhood_latitude = planningArea_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = planningArea_data.loc[0, 'Longitude'] # neighborhood longitude value

latitude = neighborhood_latitude
longitude = neighborhood_longitude
radius = 2000

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '61317dabfe724b027d784fca'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Ang Mo Kio',
#   'headerFullLocation': 'Ang Mo Kio, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 134,
#   'suggestedBounds': {'ne': {'lat': 1.3880803180000179,
#     'lng': 103.86749434775851},
#    'sw': {'lat': 1.352080281999982, 'lng': 103.8315512522415}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b15f661f964a52012b623e3',
#        'name': 'FairPrice Xtra',
#        'location': {'address': '#B2-26 AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3692792884081397,
#         'lng': 103.84888576818767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692792884081397,
#           'lng': 103.84888576818767}],
#         'distance': 113,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-26 AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b15f661f964a52012b623e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9f4875f964a520e21a37e3',
#        'name': 'Bishan - Ang Mo Kio Park',
#        'location': {'address': 'Ang Mo Kio Ave 1',
#         'lat': 1.3622192498801895,
#         'lng': 103.8462495803833,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3622192498801895,
#           'lng': 103.8462495803833}],
#         'distance': 947,
#         'postalCode': '579783',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Ave 1', '579783', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9f4875f964a520e21a37e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bea149f61aca5930d6d8300',
#        'name': 'Aramsa ~ The Garden Spa',
#        'location': {'address': '1382 Ang Mo Kio Ave 1',
#         'crossStreet': 'Bishan - Ang Mo Kio Park',
#         'lat': 1.3622918947629061,
#         'lng': 103.84760169782909,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3622918947629061,
#           'lng': 103.84760169782909}],
#         'distance': 892,
#         'postalCode': '569931',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1382 Ang Mo Kio Ave 1 (Bishan - Ang Mo Kio Park)',
#          '569931',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bea149f61aca5930d6d8300-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549a9fe5498e4c9f529e95d9',
#        'name': 'Bangkok Street Mookata',
#        'location': {'address': 'Tian Tian Lai Foodplace',
#         'crossStreet': '421 Ang Mo Kio Avenue 3',
#         'lat': 1.3656875637631025,
#         'lng': 103.85318616126993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3656875637631025,
#           'lng': 103.85318616126993}],
#         'distance': 636,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Tian Tian Lai Foodplace (421 Ang Mo Kio Avenue 3)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549a9fe5498e4c9f529e95d9-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc30123abf495215220c393',
#        'name': 'Old Chang Kee',
#        'location': {'address': 'AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Avenue 3',
#         'lat': 1.369093882325005,
#         'lng': 103.84838865753792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369093882325005,
#           'lng': 103.84838865753792}],
#         'distance': 167,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['AMK Hub (53 Ang Mo Kio Avenue 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc30123abf495215220c393-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ea04ff964a520e21c24e3',
#        'name': 'MOS Burger',
#        'location': {'address': '#01-33, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369170234303566,
#         'lng': 103.84783132985862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369170234303566,
#           'lng': 103.84783132985862}],
#         'distance': 213,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-33, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1ea04ff964a520e21c24e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51219ed9e4b0a73242920174',
#        'name': 'Central Delights',
#        'location': {'address': 'Blk C L4, ITE College Central',
#         'crossStreet': '2 Ang Mo Kio Dr.',
#         'lat': 1.3776912862128605,
#         'lng': 103.85659022598412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3776912862128605,
#           'lng': 103.85659022598412}],
#         'distance': 1156,
#         'postalCode': '567720',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk C L4, ITE College Central (2 Ang Mo Kio Dr.)',
#          '567720',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1a1941735',
#          'name': 'College Cafeteria',
#          'pluralName': 'College Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51219ed9e4b0a73242920174-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ece4dd693ad987b4a9fb4ef',
#        'name': 'NTUC FairPrice',
#        'location': {'address': 'Blk 712 Ang Mo Kio Ave 6 #01-4056',
#         'lat': 1.3715067580283722,
#         'lng': 103.84708243348618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3715067580283722,
#           'lng': 103.84708243348618}],
#         'distance': 314,
#         'postalCode': '560712',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 712 Ang Mo Kio Ave 6 #01-4056',
#          '560712',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ece4dd693ad987b4a9fb4ef-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bceddaeb6c49c7410bb9791',
#        'name': 'Subway',
#        'location': {'address': '#01-35 AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691362071202464,
#         'lng': 103.8476121994989,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691362071202464,
#           'lng': 103.8476121994989}],
#         'distance': 237,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-35 AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bceddaeb6c49c7410bb9791-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d48d8dfdae4eb0008d85e5a',
#        'name': 'A&W',
#        'location': {'address': '#B1-51/51A AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369541,
#         'lng': 103.849043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369541,
#           'lng': 103.849043}],
#         'distance': 80,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-51/51A AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d48d8dfdae4eb0008d85e5a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b06a9c8f964a52059ee22e3',
#        'name': 'Pepper Lunch',
#        'location': {'address': '#01-34, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691073953750246,
#         'lng': 103.84779052779332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691073953750246,
#           'lng': 103.84779052779332}],
#         'distance': 221,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-34, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b06a9c8f964a52059ee22e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4e516aa8fba143cab6421a',
#        'name': 'Phoon Huat & Co (Pte) Ltd',
#        'location': {'address': '422 Ang Mo Kio Ave 3, #01-2526',
#         'lat': 1.3683177603071388,
#         'lng': 103.85163895414827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3683177603071388,
#           'lng': 103.85163895414827}],
#         'distance': 306,
#         'postalCode': '560422',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['422 Ang Mo Kio Ave 3, #01-2526',
#          '560422',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4e516aa8fba143cab6421a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c92eeb7f600236a7697c132',
#        'name': "Pine Garden's Cake",
#        'location': {'address': '529 Ang Mo Kio Ave 10, #01-2369 & #01-2329',
#         'lat': 1.373054932266421,
#         'lng': 103.85584381032987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.373054932266421,
#           'lng': 103.85584381032987}],
#         'distance': 777,
#         'postalCode': '560529',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['529 Ang Mo Kio Ave 10, #01-2369 & #01-2329',
#          '560529',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c92eeb7f600236a7697c132-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5cc196775f8cfae9f2b9e0',
#        'name': 'Dog Run @ Bishan Park',
#        'location': {'address': 'Ang Mo Kio Avenue 1',
#         'lat': 1.3659666848277567,
#         'lng': 103.84402440837773,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3659666848277567,
#           'lng': 103.84402440837773}],
#         'distance': 764,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Avenue 1', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5cc196775f8cfae9f2b9e0-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b56f605364d97002c7cada9',
#        'name': 'Playmade by 丸作',
#        'location': {'lat': 1.3692572280858266,
#         'lng': 103.84972276286534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692572280858266,
#           'lng': 103.84972276286534}],
#         'distance': 94,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b56f605364d97002c7cada9-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9f647df964a520032037e3',
#        'name': 'Kam Jia Zhuang Restaurant',
#        'location': {'address': 'Blk 202 Ang Mo Kio Ave 3',
#         'lat': 1.3681666144843387,
#         'lng': 103.84411848687625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3681666144843387,
#           'lng': 103.84411848687625}],
#         'distance': 638,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 202 Ang Mo Kio Ave 3', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9f647df964a520032037e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3c8a3af964a520fa8425e3',
#        'name': '龍海鮮螃蟹王 Mellben Seafood',
#        'location': {'address': '232 Ang Mo Kio Ave 3, #01-1222',
#         'lat': 1.3683242309430559,
#         'lng': 103.83676419785981,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3683242309430559,
#           'lng': 103.83676419785981}],
#         'distance': 1433,
#         'postalCode': '560232',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['232 Ang Mo Kio Ave 3, #01-1222',
#          '560232',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3c8a3af964a520fa8425e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5667cf6201e21ef369046d',
#        'name': 'Coffee Shop, Block 422, Ang Mo Kio Ave 3',
#        'location': {'lat': 1.3681191753269961,
#         'lng': 103.85109286908205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3681191753269961,
#           'lng': 103.85109286908205}],
#         'distance': 279,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5667cf6201e21ef369046d-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e61bc951f6ef7d07a688717',
#        'name': 'ST31 Coffee Shop',
#        'location': {'address': '347 Ang Mo Kio Avenue 3',
#         'lat': 1.3674777858660376,
#         'lng': 103.84833363275743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3674777858660376,
#           'lng': 103.84833363275743}],
#         'distance': 318,
#         'postalCode': '560347',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['347 Ang Mo Kio Avenue 3',
#          '560347',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e61bc951f6ef7d07a688717-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bebcbbd61aca593d5698500',
#        'name': 'Tian Tian Dao Hokkien Fried Noodles 天天到福建炒虾面',
#        'location': {'address': '#01-12 Chong Boon Market & Food Centre',
#         'crossStreet': '453A Ang Mo Kio Ave. 10',
#         'lat': 1.3678836097612839,
#         'lng': 103.85668315024292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3678836097612839,
#           'lng': 103.85668315024292}],
#         'distance': 833,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-12 Chong Boon Market & Food Centre (453A Ang Mo Kio Ave. 10)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bebcbbd61aca593d5698500-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50712b67e4b0548504446dea',
#        'name': 'Face Ban Mian 非板面 (Ang Mo Kio)',
#        'location': {'address': '722 Ang Mo Kio Ave 8',
#         'crossStreet': 'Ang Mo Kio Central',
#         'lat': 1.3720308862082362,
#         'lng': 103.84750442817865,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3720308862082362,
#           'lng': 103.84750442817865}],
#         'distance': 312,
#         'postalCode': '560722',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['722 Ang Mo Kio Ave 8 (Ang Mo Kio Central)',
#          '560722',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50712b67e4b0548504446dea-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ced66f498eb312cf9a5f15',
#        'name': 'Prodigal Roasters',
#        'location': {'address': 'Blk 625, Ang Mo Kio Ave 9',
#         'lat': 1.3822120650112213,
#         'lng': 103.84134650230408,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3822120650112213,
#           'lng': 103.84134650230408}],
#         'distance': 1628,
#         'postalCode': '560625',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 625, Ang Mo Kio Ave 9',
#          '560625',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ced66f498eb312cf9a5f15-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed8a3a4775bcc53f85b7400',
#        'name': 'Pond Gardens',
#        'location': {'address': 'Bishan - Ang Mo Kio Park',
#         'crossStreet': 'Ang Mo Kio Ave. 1',
#         'lat': 1.3663808581988184,
#         'lng': 103.83419036865234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3663808581988184,
#           'lng': 103.83419036865234}],
#         'distance': 1755,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Bishan - Ang Mo Kio Park (Ang Mo Kio Ave. 1)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed8a3a4775bcc53f85b7400-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b408402f964a520a9b825e3',
#        'name': 'S-11 Ang Mo Kio 530 Food House',
#        'location': {'address': 'Blk 530 Ang Mo Kio Ave. 10, #01-2379',
#         'crossStreet': 'Ang Mo Kio St. 52',
#         'lat': 1.373048749151822,
#         'lng': 103.85531232732707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.373048749151822,
#           'lng': 103.85531232732707}],
#         'distance': 724,
#         'postalCode': '560530',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 530 Ang Mo Kio Ave. 10, #01-2379 (Ang Mo Kio St. 52)',
#          '560530',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b408402f964a520a9b825e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c68f51498efd710da56841',
#        'name': 'e品红麻辣香锅 Mala Hot Pot',
#        'location': {'address': 'S11 Ang Mo Kio',
#         'lat': 1.3714982901834443,
#         'lng': 103.84780316423276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3714982901834443,
#           'lng': 103.84780316423276}],
#         'distance': 248,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['S11 Ang Mo Kio', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c68f51498efd710da56841-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e17e8b918a8166f7386c8fd',
#        'name': 'Lao San Kway Chap 老三棵汁·猪什汤',
#        'location': {'address': '232 Ang Mo Kio Ave 3, #01-1222',
#         'lat': 1.3679163647082613,
#         'lng': 103.83700835178686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3679163647082613,
#           'lng': 103.83700835178686}],
#         'distance': 1413,
#         'postalCode': '560232',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['232 Ang Mo Kio Ave 3, #01-1222',
#          '560232',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e17e8b918a8166f7386c8fd-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57662f0f498e7856b64833be',
#        'name': "Collin's Grille . Bento",
#        'location': {'address': 'Ang Mo Kio Central',
#         'crossStreet': 'Jubilee Sq',
#         'lat': 1.3717133895413027,
#         'lng': 103.84752638869986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3717133895413027,
#           'lng': 103.84752638869986}],
#         'distance': 287,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Central (Jubilee Sq)', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57662f0f498e7856b64833be-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b08bbdbf964a5209a1123e3',
#        'name': 'Fitness First',
#        'location': {'address': '#B1-36, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.369249484168252,
#         'lng': 103.84858429733478,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.369249484168252,
#           'lng': 103.84858429733478}],
#         'distance': 139,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-36, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b08bbdbf964a5209a1123e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f77455498e868c8f2bbbbb',
#        'name': 'True Fitness',
#        'location': {'address': '#04-01, Djitsun Mall, 5 Ang Mo Kio Central 2',
#         'crossStreet': 'Ang Mo Kio Ave 8',
#         'lat': 1.372891267012976,
#         'lng': 103.847660805816,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.372891267012976,
#           'lng': 103.847660805816}],
#         'distance': 375,
#         'postalCode': '569663',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#04-01, Djitsun Mall, 5 Ang Mo Kio Central 2 (Ang Mo Kio Ave 8)',
#          '569663',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51f77455498e868c8f2bbbbb-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3325f666e40f47af7ac78b',
#        'name': 'Dessert Bowl 一碗甜品 (Dessert Bowl)',
#        'location': {'address': '80A Serangoon Garden Way',
#         'lat': 1.3641330827815563,
#         'lng': 103.86505613387375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3641330827815563,
#           'lng': 103.86505613387375}],
#         'distance': 1851,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['80A Serangoon Garden Way', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3325f666e40f47af7ac78b-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c50275f8edf0f473c00c5ae',
#        'name': 'Middle Rock Garden Bar',
#        'location': {'address': '1382 Ang Mo Kio Ave 1',
#         'crossStreet': 'at Bishan Park 2',
#         'lat': 1.362180530274673,
#         'lng': 103.84720301368108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.362180530274673,
#           'lng': 103.84720301368108}],
#         'distance': 916,
#         'postalCode': '569931',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1382 Ang Mo Kio Ave 1 (at Bishan Park 2)',
#          '569931',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c50275f8edf0f473c00c5ae-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d6227858daacc0008287d5e',
#        'name': 'Nic & Tom Eatery',
#        'location': {'address': '55 Serangoon Garden Way',
#         'lat': 1.363508,
#         'lng': 103.865735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.363508,
#           'lng': 103.865735}],
#         'distance': 1946,
#         'postalCode': '555951',
#         'cc': 'SG',
#         'city': 'Serangoon',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['55 Serangoon Garden Way',
#          '555951',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d6227858daacc0008287d5e-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c29e31bce3fc928dd586f88',
#        'name': 'Ang Mo Kio Swimming Complex',
#        'location': {'address': '1771 Ang Mo Kio Ave 1',
#         'lat': 1.36322106811926,
#         'lng': 103.8498029490099,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.36322106811926,
#           'lng': 103.8498029490099}],
#         'distance': 764,
#         'postalCode': '569978',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio, Singapore',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['1771 Ang Mo Kio Ave 1', '569978', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c29e31bce3fc928dd586f88-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5687adf3498e2cded5e88837',
#        'name': 'Takagi Ramen',
#        'location': {'address': '51 Ang Mo Kio Ave 3 #01-01C',
#         'crossStreet': 'Broadway Coffee Shop',
#         'lat': 1.3692634,
#         'lng': 103.847046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692634,
#           'lng': 103.847046}],
#         'distance': 290,
#         'postalCode': '560721',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['51 Ang Mo Kio Ave 3 #01-01C (Broadway Coffee Shop)',
#          '560721',
#          'Singapore']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5687adf3498e2cded5e88837-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa3bd8116fa040955368a85',
#        'name': 'Casa Manini',
#        'location': {'address': '14B Kensington Park Rd',
#         'lat': 1.365261,
#         'lng': 103.866243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.365261,
#           'lng': 103.866243}],
#         'distance': 1936,
#         'postalCode': '557264',
#         'cc': 'SG',
#         'city': 'Serangoon',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['14B Kensington Park Rd', '557264', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa3bd8116fa040955368a85-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b6bef7cb9a5a8002c117506',
#        'name': 'Starbucks',
#        'location': {'address': '#B1-65, AMK Hub',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3692298000769514,
#         'lng': 103.84868271780437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3692298000769514,
#           'lng': 103.84868271780437}],
#         'distance': 133,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-65, AMK Hub (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b6bef7cb9a5a8002c117506-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5eef6df964a5208b9e29e3',
#        'name': 'PLAYe',
#        'location': {'address': '#02-30/31, AMK HUB',
#         'crossStreet': '53 Ang Mo Kio Ave 3',
#         'lat': 1.3691085357692998,
#         'lng': 103.84822546074516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3691085357692998,
#           'lng': 103.84822546074516}],
#         'distance': 180,
#         'postalCode': '569933',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-30/31, AMK HUB (53 Ang Mo Kio Ave 3)',
#          '569933',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fb941735',
#          'name': 'Hobby Shop',
#          'pluralName': 'Hobby Shops',
#          'shortName': 'Hobbies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5eef6df964a5208b9e29e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0a18e6f964a520c02123e3',
#        'name': 'Xi Xiang Feng Yong Tau Foo 喜相逢酿豆腐',
#        'location': {'address': 'Ang Mo Kio Central Market & Food Centre, #01-23',
#         'crossStreet': '724 Ang Mo Kio Avenue 6',
#         'lat': 1.3719750629461769,
#         'lng': 103.8464082321786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3719750629461769,
#           'lng': 103.8464082321786}],
#         'distance': 405,
#         'postalCode': '560724',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Central Market & Food Centre, #01-23 (724 Ang Mo Kio Avenue 6)',
#          '560724',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0a18e6f964a520c02123e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5799ecad498ec6d503ab8a53',
#        'name': 'Mr Teh Tarik',
#        'location': {'address': 'Blk 728 Ang Mo Kio Avenue 6',
#         'crossStreet': 'Ang Mo Kio Central',
#         'lat': 1.3721677783775261,
#         'lng': 103.84560223678665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3721677783775261,
#           'lng': 103.84560223678665}],
#         'distance': 494,
#         'postalCode': '560728',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 728 Ang Mo Kio Avenue 6 (Ang Mo Kio Central)',
#          '560728',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ff',
#          'name': 'Halal Restaurant',
#          'pluralName': 'Halal Restaurants',
#          'shortName': 'Halal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5799ecad498ec6d503ab8a53-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfcbac434c1a093049a4c0e',
#        'name': 'Kebun Baru Market and Food Centre',
#        'location': {'address': '226D & 226H Ang Mo Kio St 22',
#         'lat': 1.3672418470333205,
#         'lng': 103.83985601209231,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3672418470333205,
#           'lng': 103.83985601209231}],
#         'distance': 1121,
#         'postalCode': '564226',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['226D & 226H Ang Mo Kio St 22',
#          '564226',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfcbac434c1a093049a4c0e-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c22dbd211de20a146a385ce',
#        'name': 'Bishan Sports Hall',
#        'location': {'address': '5 Bishan Street 14',
#         'lat': 1.3568645763414728,
#         'lng': 103.84908857938773,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3568645763414728,
#           'lng': 103.84908857938773}],
#         'distance': 1471,
#         'postalCode': '579784',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
# ...
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51243f60e4b02ffb6a43eeea',
#        'name': 'Soi 19 十九街 Thai Wanton Mee',
#        'location': {'address': 'Blk 151 Ang Mo Kio Ave 5',
#         'lat': 1.3770035731848176,
#         'lng': 103.84070578967811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3770035731848176,
#           'lng': 103.84070578967811}],
#         'distance': 1247,
#         'postalCode': '560151',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 151 Ang Mo Kio Ave 5',
#          '560151',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51243f60e4b02ffb6a43eeea-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529c396a11d24801c320060a',
#        'name': 'Oblong',
#        'location': {'address': '10 Maju Ave',
#         'lat': 1.3649003219942686,
#         'lng': 103.86555634034566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3649003219942686,
#           'lng': 103.86555634034566}],
#         'distance': 1875,
#         'postalCode': '556688',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['10 Maju Ave', '556688', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-529c396a11d24801c320060a-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc5633582388cfa08ef7435',
#        'name': 'Blk 409 AMK Market & Food Centre',
#        'location': {'address': '409 Ang Mo Kio Ave 10',
#         'lat': 1.36289165210107,
#         'lng': 103.8553441325199,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.36289165210107,
#           'lng': 103.8553441325199}],
#         'distance': 1029,
#         'postalCode': '560409',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['409 Ang Mo Kio Ave 10', '560409', 'Singapore']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc5633582388cfa08ef7435-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d42af8c946af04d261a0677',
#        'name': 'Burghley Squash and Tennis Centre',
#        'location': {'address': '43 Burghley Dr',
#         'lat': 1.3593546454821608,
#         'lng': 103.86069348231243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3593546454821608,
#           'lng': 103.86069348231243}],
#         'distance': 1723,
#         'postalCode': '559020',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['43 Burghley Dr', '559020', 'Singapore']},
#        'categories': [{'id': '4e39a956bd410d7aed40cbc3',
#          'name': 'Tennis Court',
#          'pluralName': 'Tennis Courts',
#          'shortName': 'Tennis Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_tennis_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d42af8c946af04d261a0677-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5714b591498e6ad52ea98b02',
#        'name': 'Swatow Seafood',
#        'location': {'address': '22 Kensington Park Road',
#         'lat': 1.3671357052599042,
#         'lng': 103.86672929935668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3671357052599042,
#           'lng': 103.86672929935668}],
#         'distance': 1942,
#         'postalCode': '557271',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['22 Kensington Park Road',
#          '557271',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5714b591498e6ad52ea98b02-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b7e242e333704294acd41',
#        'name': 'Eng Ho Fried Hokkien Prawn Mee',
#        'location': {'address': '409 Ang Mo Kio Avenue 10',
#         'crossStreet': '#01-34',
#         'lat': 1.3626698358893312,
#         'lng': 103.85555157532869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3626698358893312,
#           'lng': 103.85555157532869}],
#         'distance': 1063,
#         'postalCode': '560409',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['409 Ang Mo Kio Avenue 10 (#01-34)',
#          '560409',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b7e242e333704294acd41-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd24e869854d13a6b85fb4d',
#        'name': 'Bishan Active Park',
#        'location': {'address': 'Bishan St. 22',
#         'lat': 1.3548245096703175,
#         'lng': 103.84768419495201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3548245096703175,
#           'lng': 103.84768419495201}],
#         'distance': 1710,
#         'cc': 'SG',
#         'neighborhood': 'Bishan',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Bishan St. 22', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd24e869854d13a6b85fb4d-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c37e39dae2da593abd4ffc5',
#        'name': 'Mayflower Market & Food Centre',
#        'location': {'address': '162 Ang Mo Kio Ave 4',
#         'lat': 1.3740506635058949,
#         'lng': 103.8388794994651,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3740506635058949,
#           'lng': 103.8388794994651}],
#         'distance': 1264,
#         'postalCode': '560162',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['162 Ang Mo Kio Ave 4', '560162', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c37e39dae2da593abd4ffc5-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7dabb33633a093568d719d',
#        'name': 'Earth Jar Treasure 瓮中宝补汤',
#        'location': {'address': 'Wonderful (Coffeeshop)',
#         'crossStreet': 'Blk 22 Sin Ming Rd. #01-244.',
#         'lat': 1.3578199319742947,
#         'lng': 103.8392075781475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3578199319742947,
#           'lng': 103.8392075781475}],
#         'distance': 1783,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Wonderful (Coffeeshop) (Blk 22 Sin Ming Rd. #01-244.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'shortName': 'Soup',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7dabb33633a093568d719d-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5691144e498eb2b8eab3d4ec',
#        'name': "McDonald's",
#        'location': {'address': 'Bishan Ang Mo Kio Park',
#         'lat': 1.360912,
#         'lng': 103.846485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.360912,
#           'lng': 103.846485}],
#         'distance': 1075,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Bishan Ang Mo Kio Park', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5691144e498eb2b8eab3d4ec-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b13a27ef964a520269823e3',
#        'name': 'Bishan Stadium',
#        'location': {'address': '7 Bishan St 14',
#         'crossStreet': 'Bishan Sports Hall',
#         'lat': 1.3568554353761297,
#         'lng': 103.84914372337403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3568554353761297,
#           'lng': 103.84914372337403}],
#         'distance': 1472,
#         'postalCode': '579784',
#         'cc': 'SG',
#         'neighborhood': 'Bishan',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['7 Bishan St 14 (Bishan Sports Hall)',
#          '579784',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d184941735',
#          'name': 'Stadium',
#          'pluralName': 'Stadiums',
#          'shortName': 'Stadium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b13a27ef964a520269823e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cefa2364cd4236a0a8db363',
#        'name': 'NTUC FairPrice',
#        'location': {'address': '279 Bishan St 24, #01-62/64',
#         'lat': 1.3571740202739844,
#         'lng': 103.84389843205567,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3571740202739844,
#           'lng': 103.84389843205567}],
#         'distance': 1567,
#         'postalCode': '570279',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['279 Bishan St 24, #01-62/64',
#          '570279',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cefa2364cd4236a0a8db363-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57d12fd6498e1fc60b9bfd20',
#        'name': 'Sumo Big Prawn',
#        'location': {'address': '#01-72 628 Ang Mo Kio Market & Food Centre',
#         'crossStreet': '628 Ang Mo Kio Ave 4',
#         'lat': 1.3811210843779824,
#         'lng': 103.84077843127767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3811210843779824,
#           'lng': 103.84077843127767}],
#         'distance': 1567,
#         'postalCode': '560628',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio, Singapore',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-72 628 Ang Mo Kio Market & Food Centre (628 Ang Mo Kio Ave 4)',
#          '560628',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57d12fd6498e1fc60b9bfd20-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf0f44f6195721e48933ec1',
#        'name': 'The Bodyshop @ Junction8',
#        'location': {'lat': 1.3545469601379936,
#         'lng': 103.84889893277766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3545469601379936,
#           'lng': 103.84889893277766}],
#         'distance': 1730,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf0f44f6195721e48933ec1-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                        name   categories       lat         lng
# 0            FairPrice Xtra  Supermarket  1.369279  103.848886
# 1  Bishan - Ang Mo Kio Park         Park  1.362219  103.846250
# 2   Aramsa ~ The Garden Spa          Spa  1.362292  103.847602
# 3    Bangkok Street Mookata    BBQ Joint  1.365688  103.853186
# 4             Old Chang Kee  Snack Place  1.369094  103.848389

# %% [markdown]
# <font size="4">Exploring the districts of Singapore</font>

# %% [markdown]
# First, define a function that can be used to search for venues in each district of Singapore.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
singapore_venues=getNearbyVenues(list(planningArea_data["Planning Area"]),list(planningArea_data['Latitude']),list(planningArea_data['Longitude']))
print(singapore_venues.shape)
singapore_venues.head()
# Out:
# Ang Mo Kio
# Bedok
# Bishan
# Boon Lay
# Bukit Batok
# Bukit Merah
# Bukit Panjang
# Bukit Timah
# Central Water Catchment
# Changi
# Changi Bay
# Choa Chu Kang
# Clementi
# Downtown Core
# Geylang
# Hougang
# Jurong East
# Jurong West
# Kallang
# Lim Chu Kang
# Mandai
# Marina East
# Marina South
# Marine Parade
# Museum
# Newton
# North-Eastern Islands
# Novena
# Orchard
# Outram
# Pasir Ris
# Paya Lebar
# Pioneer
# Punggol
# Queenstown
# River Valley
# Rochor
# Seletar
# Sembawang
# Sengkang
# Serangoon
# Simpang
# Singapore River
# Southern Islands
# Straits View
# Sungei Kadut
# Tampines
# Tanglin
# Tengah
# Toa Payoh
# Tuas
# Western Islands
# Western Water Catchment
# Woodlands
# Yishun
# (1675, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude           Venue  \
# 0   Ang Mo Kio                1.37008              103.849523  FairPrice Xtra
# 1   Ang Mo Kio                1.37008              103.849523   Old Chang Kee
# 2   Ang Mo Kio                1.37008              103.849523      MOS Burger
# 3   Ang Mo Kio                1.37008              103.849523             A&W
# 4   Ang Mo Kio                1.37008              103.849523          Subway
#
#    Venue Latitude  Venue Longitude        Venue Category
# 0        1.369279       103.848886           Supermarket
# 1        1.369094       103.848389           Snack Place
# 2        1.369170       103.847831          Burger Joint
# 3        1.369541       103.849043  Fast Food Restaurant
# 4        1.369136       103.847612        Sandwich Place

# %% [markdown]
# This dataframe contains over 1600 venues. Let us check the number of venues found in each district.

# %%
singapore_venues.groupby('Neighborhood').count()
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Ang Mo Kio                                  41                      41     41
# Bedok                                       58                      58     58
# Bishan                                      43                      43     43
# Boon Lay                                    70                      70     70
# Bukit Batok                                 19                      19     19
# Bukit Merah                                 21                      21     21
# Bukit Panjang                               57                      57     57
# Bukit Timah                                 11                      11     11
# Central Water Catchment                      3                       3      3
# Changi                                       7                       7      7
# Changi Bay                                   6                       6      6
# Choa Chu Kang                               23                      23     23
# Clementi                                    66                      66     66
# Downtown Core                               55                      55     55
# Geylang                                     32                      32     32
# Hougang                                     37                      37     37
# Jurong East                                 70                      70     70
# Jurong West                                 63                      63     63
# Kallang                                      5                       5      5
# Lim Chu Kang                                 3                       3      3
# Mandai                                       1                       1      1
# Marina East                                  4                       4      4
# Marina South                                 5                       5      5
# Marine Parade                               37                      37     37
# Museum                                      37                      37     37
# Newton                                      28                      28     28
# Novena                                      67                      67     67
# Orchard                                    100                     100    100
# Outram                                      11                      11     11
# Pasir Ris                                   33                      33     33
# Paya Lebar                                  78                      78     78
# Pioneer                                     16                      16     16
# Punggol                                     47                      47     47
# Queenstown                                  17                      17     17
# River Valley                                19                      19     19
# Rochor                                      26                      26     26
# Seletar                                      4                       4      4
# Sembawang                                   24                      24     24
# Sengkang                                    27                      27     27
# Serangoon                                   38                      38     38
# Simpang                                      2                       2      2
# Singapore River                            100                     100    100
# Straits View                                 1                       1      1
# Sungei Kadut                                 5                       5      5
# Tampines                                    83                      83     83
# Tanglin                                     23                      23     23
# Toa Payoh                                   51                      51     51
# Tuas                                         2                       2      2
# Western Water Catchment                      1                       1      1
# Woodlands                                   53                      53     53
# Yishun                                      45                      45     45
#
#                          Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Ang Mo Kio                           41               41              41
# Bedok                                58               58              58
# Bishan                               43               43              43
# Boon Lay                             70               70              70
# Bukit Batok                          19               19              19
# Bukit Merah                          21               21              21
# Bukit Panjang                        57               57              57
# Bukit Timah                          11               11              11
# Central Water Catchment               3                3               3
# Changi                                7                7               7
# Changi Bay                            6                6               6
# Choa Chu Kang                        23               23              23
# Clementi                             66               66              66
# Downtown Core                        55               55              55
# Geylang                              32               32              32
# Hougang                              37               37              37
# Jurong East                          70               70              70
# Jurong West                          63               63              63
# Kallang                               5                5               5
# Lim Chu Kang                          3                3               3
# Mandai                                1                1               1
# Marina East                           4                4               4
# Marina South                          5                5               5
# Marine Parade                        37               37              37
# Museum                               37               37              37
# Newton                               28               28              28
# Novena                               67               67              67
# Orchard                             100              100             100
# Outram                               11               11              11
# Pasir Ris                            33               33              33
# Paya Lebar                           78               78              78
# Pioneer                              16               16              16
# Punggol                              47               47              47
# Queenstown                           17               17              17
# River Valley                         19               19              19
# Rochor                               26               26              26
# Seletar                               4                4               4
# Sembawang                            24               24              24
# Sengkang                             27               27              27
# Serangoon                            38               38              38
# Simpang                               2                2               2
# Singapore River                     100              100             100
# Straits View                          1                1               1
# Sungei Kadut                          5                5               5
# Tampines                             83               83              83
# Tanglin                              23               23              23
# Toa Payoh                            51               51              51
# Tuas                                  2                2               2
# Western Water Catchment               1                1               1
# Woodlands                            53               53              53
# Yishun                               45               45              45

# %% [markdown]
# <font size="4">Types of venues in each neighborhood.</font>

# %% [markdown]
# Next, we would like to see what kinds of venues are most common in each Singapore neighborhood. First, we perform one-hot encoding for each venue.

# %%
# one hot encoding
singapore_onehot = pd.get_dummies(singapore_venues[['Venue Category']], prefix="", prefix_sep="")
singapore_onehot.drop(['Neighborhood'], axis=1,inplace = True)
singapore_onehot.insert(loc=0, column='Neighborhood', value=singapore_venues['Neighborhood'] )

# %% [markdown]
# Next, group the venues by their neighborhoods and calculate the mean frequency for each venue category.

# %%
singapore_grouped = singapore_onehot.groupby('Neighborhood').mean().reset_index()
singapore_grouped
# Out:
#                Neighborhood       ATM  Accessories Store   Airport  \
# 0                Ang Mo Kio  0.000000           0.000000  0.000000
# 1                     Bedok  0.000000           0.000000  0.000000
# 2                    Bishan  0.000000           0.000000  0.000000
# 3                  Boon Lay  0.000000           0.000000  0.000000
# 4               Bukit Batok  0.000000           0.000000  0.000000
# 5               Bukit Merah  0.000000           0.000000  0.000000
# 6             Bukit Panjang  0.000000           0.000000  0.000000
# 7               Bukit Timah  0.000000           0.000000  0.000000
# 8   Central Water Catchment  0.000000           0.000000  0.000000
# 9                    Changi  0.000000           0.000000  0.285714
# 10               Changi Bay  0.000000           0.000000  0.000000
# 11            Choa Chu Kang  0.000000           0.000000  0.000000
# 12                 Clementi  0.015152           0.000000  0.000000
# 13            Downtown Core  0.000000           0.000000  0.000000
# 14                  Geylang  0.000000           0.000000  0.000000
# 15                  Hougang  0.000000           0.000000  0.000000
# 16              Jurong East  0.000000           0.014286  0.000000
# 17              Jurong West  0.000000           0.000000  0.000000
# 18                  Kallang  0.000000           0.000000  0.000000
# 19             Lim Chu Kang  0.000000           0.000000  0.000000
# 20                   Mandai  0.000000           0.000000  0.000000
# 21              Marina East  0.000000           0.000000  0.000000
# 22             Marina South  0.000000           0.000000  0.000000
# 23            Marine Parade  0.000000           0.000000  0.000000
# 24                   Museum  0.000000           0.000000  0.000000
# 25                   Newton  0.000000           0.000000  0.000000
# 26                   Novena  0.000000           0.000000  0.000000
# 27                  Orchard  0.000000           0.000000  0.000000
# 28                   Outram  0.000000           0.000000  0.000000
# 29                Pasir Ris  0.000000           0.000000  0.000000
# 30               Paya Lebar  0.000000           0.000000  0.000000
# 31                  Pioneer  0.000000           0.000000  0.000000
# 32                  Punggol  0.000000           0.000000  0.000000
# 33               Queenstown  0.000000           0.000000  0.000000
# 34             River Valley  0.000000           0.000000  0.000000
# 35                   Rochor  0.000000           0.000000  0.000000
# 36                  Seletar  0.000000           0.000000  0.000000
# 37                Sembawang  0.041667           0.000000  0.000000
# 38                 Sengkang  0.000000           0.000000  0.000000
# 39                Serangoon  0.000000           0.000000  0.000000
# 40                  Simpang  0.000000           0.000000  0.000000
# 41          Singapore River  0.000000           0.000000  0.000000
# 42             Straits View  0.000000           0.000000  0.000000
# 43             Sungei Kadut  0.000000           0.000000  0.000000
# 44                 Tampines  0.000000           0.000000  0.000000
# 45                  Tanglin  0.000000           0.000000  0.000000
# 46                Toa Payoh  0.000000           0.000000  0.000000
# 47                     Tuas  0.000000           0.000000  0.000000
# 48  Western Water Catchment  0.000000           0.000000  0.000000
# 49                Woodlands  0.000000           0.000000  0.000000
# 50                   Yishun  0.000000           0.000000  0.000000
#
#     Airport Terminal  American Restaurant    Arcade  Art Gallery  Art Museum  \
# 0           0.000000             0.000000  0.000000     0.000000    0.000000
# 1           0.000000             0.017241  0.000000     0.000000    0.000000
# 2           0.000000             0.000000  0.000000     0.000000    0.000000
# 3           0.000000             0.014286  0.000000     0.000000    0.000000
# 4           0.000000             0.000000  0.000000     0.000000    0.000000
# 5           0.000000             0.000000  0.000000     0.000000    0.000000
# 6           0.000000             0.035088  0.000000     0.000000    0.000000
# 7           0.000000             0.000000  0.000000     0.000000    0.000000
# 8           0.000000             0.000000  0.000000     0.000000    0.000000
# 9           0.285714             0.000000  0.000000     0.000000    0.000000
# 10          0.000000             0.000000  0.000000     0.000000    0.000000
# 11          0.000000             0.000000  0.000000     0.000000    0.000000
# 12          0.000000             0.015152  0.000000     0.000000    0.000000
# 13          0.000000             0.000000  0.000000     0.000000    0.000000
# 14          0.000000             0.000000  0.000000     0.000000    0.000000
# 15          0.000000             0.000000  0.000000     0.000000    0.000000
# 16          0.000000             0.000000  0.000000     0.000000    0.000000
# 17          0.000000             0.015873  0.000000     0.000000    0.000000
# 18          0.000000             0.000000  0.000000     0.000000    0.000000
# 19          0.000000             0.000000  0.000000     0.000000    0.000000
# 20          0.000000             0.000000  0.000000     0.000000    0.000000
# 21          0.000000             0.000000  0.000000     0.000000    0.000000
# 22          0.000000             0.000000  0.000000     0.000000    0.000000
# 23          0.000000             0.000000  0.000000     0.000000    0.000000
# 24          0.000000             0.000000  0.000000     0.027027    0.027027
# 25          0.000000             0.000000  0.000000     0.000000    0.000000
# 26          0.000000             0.000000  0.000000     0.000000    0.000000
# 27          0.000000             0.010000  0.000000     0.000000    0.000000
# 28          0.000000             0.000000  0.000000     0.000000    0.000000
# 29          0.000000             0.000000  0.000000     0.000000    0.000000
# 30          0.000000             0.000000  0.000000     0.000000    0.000000
# 31          0.000000             0.000000  0.000000     0.000000    0.000000
# 32          0.000000             0.000000  0.000000     0.000000    0.000000
# 33          0.000000             0.000000  0.000000     0.000000    0.000000
# 34          0.000000             0.000000  0.000000     0.000000    0.000000
# 35          0.000000             0.000000  0.000000     0.038462    0.000000
# 36          0.000000             0.000000  0.000000     0.000000    0.000000
# 37          0.000000             0.000000  0.000000     0.000000    0.000000
# 38          0.000000             0.000000  0.037037     0.000000    0.000000
# 39          0.000000             0.000000  0.000000     0.000000    0.000000
# 40          0.000000             0.000000  0.000000     0.000000    0.000000
# 41          0.000000             0.010000  0.000000     0.000000    0.000000
# 42          0.000000             0.000000  0.000000     0.000000    0.000000
# 43          0.000000             0.000000  0.000000     0.200000    0.000000
# 44          0.000000             0.012048  0.000000     0.000000    0.000000
# 45          0.000000             0.000000  0.000000     0.000000    0.043478
# 46          0.000000             0.000000  0.000000     0.000000    0.000000
# 47          0.000000             0.000000  0.000000     0.000000    0.000000
# 48          0.000000             0.000000  0.000000     0.000000    0.000000
# 49          0.000000             0.000000  0.018868     0.000000    0.000000
# 50          0.000000             0.000000  0.022222     0.000000    0.000000
#
#     Arts & Crafts Store  ...  Video Game Store  Video Store  \
# 0              0.000000  ...          0.000000     0.000000
# 1              0.000000  ...          0.000000     0.000000
# 2              0.000000  ...          0.000000     0.000000
# 3              0.000000  ...          0.000000     0.014286
# 4              0.000000  ...          0.000000     0.000000
# 5              0.000000  ...          0.000000     0.000000
# 6              0.000000  ...          0.000000     0.000000
# 7              0.000000  ...          0.000000     0.000000
# 8              0.000000  ...          0.000000     0.000000
# 9              0.000000  ...          0.000000     0.000000
# 10             0.000000  ...          0.000000     0.000000
# 11             0.000000  ...          0.000000     0.000000
# 12             0.015152  ...          0.015152     0.000000
# 13             0.000000  ...          0.000000     0.000000
# 14             0.000000  ...          0.000000     0.000000
# 15             0.000000  ...          0.000000     0.000000
# 16             0.000000  ...          0.000000     0.000000
# 17             0.000000  ...          0.000000     0.015873
# 18             0.000000  ...          0.000000     0.000000
# 19             0.000000  ...          0.000000     0.000000
# 20             0.000000  ...          0.000000     0.000000
# 21             0.000000  ...          0.000000     0.000000
# 22             0.000000  ...          0.000000     0.000000
# 23             0.000000  ...          0.000000     0.000000
# 24             0.000000  ...          0.000000     0.000000
# 25             0.000000  ...          0.000000     0.000000
# 26             0.000000  ...          0.000000     0.000000
# 27             0.000000  ...          0.000000     0.000000
# 28             0.000000  ...          0.000000     0.000000
# 29             0.000000  ...          0.000000     0.000000
# 30             0.000000  ...          0.000000     0.000000
# 31             0.000000  ...          0.000000     0.000000
# 32             0.000000  ...          0.000000     0.000000
# 33             0.000000  ...          0.000000     0.000000
# 34             0.000000  ...          0.000000     0.000000
# 35             0.000000  ...          0.000000     0.000000
# 36             0.000000  ...          0.000000     0.000000
# 37             0.000000  ...          0.000000     0.000000
# 38             0.000000  ...          0.000000     0.000000
# 39             0.000000  ...          0.000000     0.000000
# 40             0.000000  ...          0.000000     0.000000
# 41             0.000000  ...          0.000000     0.000000
# 42             0.000000  ...          0.000000     0.000000
# 43             0.000000  ...          0.000000     0.000000
# 44             0.000000  ...          0.000000     0.000000
# 45             0.000000  ...          0.000000     0.000000
# 46             0.000000  ...          0.000000     0.000000
# 47             0.000000  ...          0.000000     0.000000
# 48             0.000000  ...          0.000000     0.000000
# 49             0.000000  ...          0.000000     0.000000
# 50             0.000000  ...          0.022222     0.000000
#
#     Vietnamese Restaurant  Water Park  Waterfront  Whisky Bar  Wine Shop  \
# 0                0.000000    0.000000    0.000000    0.000000       0.00
# 1                0.000000    0.000000    0.000000    0.000000       0.00
# 2                0.000000    0.000000    0.000000    0.000000       0.00
# 3                0.000000    0.000000    0.000000    0.000000       0.00
# 4                0.000000    0.000000    0.000000    0.000000       0.00
# 5                0.000000    0.000000    0.000000    0.000000       0.00
# 6                0.000000    0.017544    0.000000    0.000000       0.00
# 7                0.000000    0.000000    0.000000    0.000000       0.00
# 8                0.000000    0.000000    0.000000    0.000000       0.00
# 9                0.000000    0.000000    0.000000    0.000000       0.00
# 10               0.000000    0.000000    0.000000    0.000000       0.00
# 11               0.000000    0.000000    0.000000    0.000000       0.00
# 12               0.000000    0.000000    0.000000    0.000000       0.00
# 13               0.000000    0.000000    0.036364    0.000000       0.00
# 14               0.000000    0.000000    0.000000    0.000000       0.00
# 15               0.000000    0.000000    0.000000    0.000000       0.00
# 16               0.000000    0.000000    0.000000    0.000000       0.00
# 17               0.000000    0.000000    0.000000    0.000000       0.00
# 18               0.000000    0.000000    0.000000    0.000000       0.00
# 19               0.000000    0.000000    0.000000    0.000000       0.00
# 20               0.000000    0.000000    0.000000    0.000000       0.00
# 21               0.000000    0.000000    0.000000    0.000000       0.00
# 22               0.000000    0.000000    0.000000    0.000000       0.00
# 23               0.000000    0.000000    0.000000    0.000000       0.00
# 24               0.000000    0.000000    0.000000    0.027027       0.00
# 25               0.000000    0.000000    0.000000    0.000000       0.00
# 26               0.014925    0.000000    0.000000    0.000000       0.00
# 27               0.000000    0.000000    0.000000    0.000000       0.00
# 28               0.000000    0.000000    0.000000    0.000000       0.00
# 29               0.000000    0.000000    0.000000    0.000000       0.00
# 30               0.012821    0.000000    0.000000    0.000000       0.00
# 31               0.000000    0.000000    0.000000    0.000000       0.00
# 32               0.021277    0.000000    0.000000    0.000000       0.00
# 33               0.000000    0.000000    0.000000    0.000000       0.00
# 34               0.000000    0.000000    0.000000    0.000000       0.00
# 35               0.000000    0.000000    0.000000    0.000000       0.00
# 36               0.000000    0.000000    0.000000    0.000000       0.00
# 37               0.000000    0.000000    0.000000    0.000000       0.00
# 38               0.000000    0.000000    0.000000    0.000000       0.00
# 39               0.000000    0.000000    0.000000    0.000000       0.00
# 40               0.000000    0.000000    0.000000    0.000000       0.00
# 41               0.020000    0.000000    0.010000    0.000000       0.01
# 42               0.000000    0.000000    0.000000    0.000000       0.00
# 43               0.000000    0.000000    0.000000    0.000000       0.00
# 44               0.000000    0.000000    0.000000    0.000000       0.00
# 45               0.000000    0.000000    0.000000    0.000000       0.00
# 46               0.000000    0.000000    0.000000    0.000000       0.00
# 47               0.000000    0.000000    0.000000    0.000000       0.00
# 48               0.000000    0.000000    0.000000    0.000000       0.00
# 49               0.000000    0.000000    0.000000    0.000000       0.00
# 50               0.000000    0.000000    0.000000    0.000000       0.00
#
#     Wings Joint  Yoga Studio  Zoo Exhibit
# 0      0.000000     0.000000     0.000000
# 1      0.017241     0.000000     0.000000
# 2      0.000000     0.000000     0.000000
# 3      0.014286     0.000000     0.000000
# 4      0.000000     0.000000     0.000000
# 5      0.000000     0.000000     0.000000
# 6      0.000000     0.000000     0.000000
# 7      0.000000     0.000000     0.000000
# 8      0.000000     0.000000     0.000000
# 9      0.000000     0.000000     0.000000
# 10     0.000000     0.000000     0.000000
# 11     0.000000     0.000000     0.000000
# 12     0.000000     0.000000     0.000000
# 13     0.000000     0.018182     0.000000
# 14     0.031250     0.000000     0.000000
# 15     0.000000     0.000000     0.000000
# 16     0.000000     0.000000     0.000000
# 17     0.015873     0.000000     0.000000
# 18     0.000000     0.000000     0.000000
# 19     0.000000     0.000000     0.333333
# 20     0.000000     0.000000     0.000000
# 21     0.000000     0.000000     0.000000
# 22     0.000000     0.000000     0.000000
# 23     0.000000     0.027027     0.000000
# 24     0.000000     0.027027     0.000000
# 25     0.000000     0.000000     0.000000
# 26     0.000000     0.000000     0.000000
# 27     0.000000     0.010000     0.000000
# 28     0.000000     0.000000     0.000000
# 29     0.000000     0.000000     0.000000
# 30     0.000000     0.000000     0.000000
# 31     0.000000     0.000000     0.000000
# 32     0.000000     0.000000     0.000000
# 33     0.000000     0.000000     0.000000
# 34     0.000000     0.000000     0.000000
# 35     0.000000     0.000000     0.000000
# 36     0.000000     0.000000     0.000000
# 37     0.000000     0.000000     0.000000
# 38     0.000000     0.000000     0.000000
# 39     0.000000     0.000000     0.000000
# 40     0.000000     0.000000     0.000000
# 41     0.010000     0.010000     0.000000
# 42     0.000000     0.000000     0.000000
# 43     0.000000     0.000000     0.000000
# 44     0.000000     0.000000     0.000000
# 45     0.000000     0.000000     0.000000
# 46     0.000000     0.000000     0.000000
# 47     0.000000     0.000000     0.000000
# 48     0.000000     0.000000     0.000000
# 49     0.000000     0.000000     0.000000
# 50     0.000000     0.000000     0.000000
#
# [51 rows x 221 columns]

# %% [markdown]
# We can look at the top five most common venues for each neighborhood.

# %%
num_top_venues = 5

for hood in singapore_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = singapore_grouped[singapore_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Ang Mo Kio----
#              venue  freq
# 0      Coffee Shop  0.10
# 1  Bubble Tea Shop  0.07
# 2       Food Court  0.07
# 3     Dessert Shop  0.07
# 4      Supermarket  0.05
#
#
# ----Bedok----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1          Food Court  0.05
# 2        Noodle House  0.05
# 3  Chinese Restaurant  0.05
# 4    Asian Restaurant  0.05
#
#
# ----Bishan----
#               venue  freq
# 0        Food Court  0.09
# 1       Coffee Shop  0.09
# 2    Ice Cream Shop  0.07
# 3   Bubble Tea Shop  0.07
# 4  Asian Restaurant  0.05
#
#
# ----Boon Lay----
#                   venue  freq
# 0   Japanese Restaurant  0.11
# 1      Asian Restaurant  0.10
# 2  Fast Food Restaurant  0.09
# 3    Chinese Restaurant  0.06
# 4          Dessert Shop  0.06
#
#
# ----Bukit Batok----
#                            venue  freq
# 0                    Coffee Shop  0.21
# 1                     Food Court  0.11
# 2             Chinese Restaurant  0.11
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                           Café  0.05
#
#
# ----Bukit Merah----
#                 venue  freq
# 0  Chinese Restaurant  0.14
# 1          Food Court  0.14
# 2                Café  0.10
# 3                 Gym  0.10
# 4         Karaoke Bar  0.10
#
#
# ----Bukit Panjang----
#                   venue  freq
# 0      Sushi Restaurant  0.07
# 1     Korean Restaurant  0.05
# 2      Asian Restaurant  0.05
# 3  Fast Food Restaurant  0.05
# 4       Bubble Tea Shop  0.04
#
#
# ----Bukit Timah----
#               venue  freq
# 0             Trail  0.64
# 1    Scenic Lookout  0.18
# 2              Hill  0.09
# 3         Rest Area  0.09
# 4  Pedestrian Plaza  0.00
#
#
# ----Central Water Catchment----
#               venue  freq
# 0         Reservoir  0.67
# 1  Business Service  0.33
# 2               ATM  0.00
# 3  Pedestrian Plaza  0.00
# 4      Night Market  0.00
#
#
# ----Changi----
#               venue  freq
# 0           Airport  0.29
# 1  Airport Terminal  0.29
# 2        Food Court  0.14
# 3             Hotel  0.14
# 4         Rest Area  0.14
#
#
# ----Changi Bay----
#             venue  freq
# 0   Boat or Ferry  0.33
# 1      Smoke Shop  0.17
# 2     Pizza Place  0.17
# 3        Gym Pool  0.17
# 4  History Museum  0.17
#
#
# ----Choa Chu Kang----
#                   venue  freq
# 0           Snack Place  0.09
# 1                  Café  0.09
# 2  Fast Food Restaurant  0.09
# 3           Coffee Shop  0.09
# 4            Food Court  0.09
#
#
# ----Clementi----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1            Food Court  0.08
# 2      Asian Restaurant  0.06
# 3  Fast Food Restaurant  0.05
# 4    Chinese Restaurant  0.05
#
#
# ----Downtown Core----
#                   venue  freq
# 0          Concert Hall  0.05
# 1  Gym / Fitness Center  0.05
# 2           Salad Place  0.04
# 3                 Hotel  0.04
# 4          Cocktail Bar  0.04
#
#
# ----Geylang----
#                            venue  freq
# 0             Chinese Restaurant  0.22
# 1                   Noodle House  0.09
# 2                     Food Court  0.09
# 3  Vegetarian / Vegan Restaurant  0.09
# 4               Asian Restaurant  0.06
#
#
# ----Hougang----
#                   venue  freq
# 0            Food Court  0.11
# 1  Fast Food Restaurant  0.08
# 2    Chinese Restaurant  0.08
# 3                  Café  0.05
# 4           Supermarket  0.05
#
#
# ----Jurong East----
#                  venue  freq
# 0           Food Court  0.07
# 1                 Café  0.07
# 2  Japanese Restaurant  0.07
# 3   Chinese Restaurant  0.07
# 4          Coffee Shop  0.07
#
#
# ----Jurong West----
#                   venue  freq
# 0   Japanese Restaurant  0.13
# 1      Asian Restaurant  0.11
# 2  Fast Food Restaurant  0.10
# 3    Chinese Restaurant  0.06
# 4          Dessert Shop  0.05
#
#
# ----Kallang----
#               venue  freq
# 0            Hostel   0.2
# 1        Restaurant   0.2
# 2       Supermarket   0.2
# 3       Coffee Shop   0.2
# 4  Asian Restaurant   0.2
#
#
# ----Lim Chu Kang----
#          venue  freq
# 0  Zoo Exhibit  0.33
# 1         Farm  0.33
# 2    Gift Shop  0.33
# 3    Juice Bar  0.00
# 4  Karaoke Bar  0.00
#
#
# ----Mandai----
#               venue  freq
# 0  Asian Restaurant   1.0
# 1               ATM   0.0
# 2  Pedestrian Plaza   0.0
# 3         Newsstand   0.0
# 4      Night Market   0.0
#
#
# ----Marina East----
#               venue  freq
# 0              Park  0.50
# 1              Café  0.25
# 2      Home Service  0.25
# 3               ATM  0.00
# 4  Pedestrian Plaza  0.00
#
#
# ----Marina South----
#                  venue  freq
# 0               Garden   0.4
# 1                 Park   0.2
# 2  Government Building   0.2
# 3           Public Art   0.2
# 4                 Pool   0.0
#
#
# ----Marine Parade----
#                  venue  freq
# 0                Hotel  0.11
# 1  Japanese Restaurant  0.08
# 2            Multiplex  0.08
# 3       Massage Studio  0.08
# 4   Chinese Restaurant  0.05
#
#
# ----Museum----
#                  venue  freq
# 0                Hotel  0.11
# 1  Japanese Restaurant  0.08
# 2         Dessert Shop  0.08
# 3      Bubble Tea Shop  0.05
# 4       Cosmetics Shop  0.05
#
#
# ----Newton----
#                 venue  freq
# 0  Chinese Restaurant  0.21
# 1  Seafood Restaurant  0.14
# 2  Italian Restaurant  0.07
# 3           Hotel Bar  0.07
# 4     Thai Restaurant  0.04
#
#
# ----Novena----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.09
# 2    Asian Restaurant  0.07
# 3               Hotel  0.06
# 4  Italian Restaurant  0.04
#
#
# ----Orchard----
#                  venue  freq
# 0             Boutique  0.09
# 1  Japanese Restaurant  0.08
# 2               Bakery  0.06
# 3     Sushi Restaurant  0.05
# 4                Hotel  0.05
#
#
# ----Outram----
#                 venue  freq
# 0  Dim Sum Restaurant  0.09
# 1               Hotel  0.09
# 2  Spanish Restaurant  0.09
# 3          Nail Salon  0.09
# 4       Grocery Store  0.09
#
#
# ----Pasir Ris----
#                   venue  freq
# 0                Bakery  0.09
# 1            Food Court  0.09
# 2    Italian Restaurant  0.06
# 3  Fast Food Restaurant  0.06
# 4        Sandwich Place  0.06
#
#
# ----Paya Lebar----
#                   venue  freq
# 0  Fast Food Restaurant  0.08
# 1         Shopping Mall  0.08
# 2            Food Court  0.05
# 3    Chinese Restaurant  0.05
# 4      Asian Restaurant  0.05
#
#
# ----Pioneer----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1   Convenience Store  0.12
# 2            Bus Stop  0.06
# 3    Asian Restaurant  0.06
# 4  Seafood Restaurant  0.06
#
#
# ----Punggol----
#                  venue  freq
# 0     Sushi Restaurant  0.06
# 1  Japanese Restaurant  0.06
# 2   Chinese Restaurant  0.06
# 3       Discount Store  0.04
# 4          Supermarket  0.04
#
#
# ----Queenstown----
#                 venue  freq
# 0          Food Court  0.18
# 1  Chinese Restaurant  0.12
# 2        Noodle House  0.12
# 3  Italian Restaurant  0.06
# 4       Train Station  0.06
#
#
# ----River Valley----
#                  venue  freq
# 0               Bakery  0.16
# 1                 Café  0.11
# 2        Grocery Store  0.05
# 3           Shoe Store  0.05
# 4  Fried Chicken Joint  0.05
#
#
# ----Rochor----
#                            venue  freq
# 0              Indian Restaurant  0.35
# 1  Vegetarian / Vegan Restaurant  0.19
# 2             Chinese Restaurant  0.08
# 3               Ramen Restaurant  0.04
# 4                     Restaurant  0.04
#
#
# ----Seletar----
#              venue  freq
# 0      Snack Place  0.25
# 1             Café  0.25
# 2  Harbor / Marina  0.25
# 3       Food Court  0.25
# 4              ATM  0.00
#
#
# ----Sembawang----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1  Fast Food Restaurant  0.08
# 2           Bus Station  0.08
# 3    Chinese Restaurant  0.08
# 4                   ATM  0.04
#
#
# ----Sengkang----
#                   venue  freq
# 0  Fast Food Restaurant  0.11
# 1      Sushi Restaurant  0.07
# 2            Food Court  0.07
# 3           Coffee Shop  0.07
# 4      Asian Restaurant  0.07
#
#
# ----Serangoon----
#                  venue  freq
# 0   Chinese Restaurant  0.08
# 1          Coffee Shop  0.08
# 2  Japanese Restaurant  0.05
# 3       Clothing Store  0.05
# 4       Ice Cream Shop  0.05
#
#
# ----Simpang----
#               venue  freq
# 0             Diner   0.5
# 1          Platform   0.5
# 2               ATM   0.0
# 3  Pedestrian Plaza   0.0
# 4      Night Market   0.0
#
#
# ----Singapore River----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1                Hotel  0.07
# 2            Nightclub  0.06
# 3      Thai Restaurant  0.04
# 4   Italian Restaurant  0.03
#
#
# ----Straits View----
#            venue  freq
# 0  Boat or Ferry   1.0
# 1            ATM   0.0
# 2         Museum   0.0
# 3      Newsstand   0.0
# 4   Night Market   0.0
#
#
# ----Sungei Kadut----
#          venue  freq
# 0  Bus Station   0.4
# 1  Art Gallery   0.2
# 2       Office   0.2
# 3        Hotel   0.2
# 4          ATM   0.0
#
#
# ----Tampines----
#                 venue  freq
# 0                Café  0.07
# 1              Bakery  0.06
# 2         Coffee Shop  0.05
# 3                 Gym  0.05
# 4  Chinese Restaurant  0.04
#
#
# ----Tanglin----
#                         venue  freq
# 0                      Bakery  0.09
# 1                        Park  0.09
# 2             Thai Restaurant  0.09
# 3           French Restaurant  0.09
# 4  Tourist Information Center  0.04
#
#
# ----Toa Payoh----
#                 venue  freq
# 0        Noodle House  0.16
# 1  Chinese Restaurant  0.12
# 2          Food Court  0.10
# 3    Asian Restaurant  0.08
# 4         Snack Place  0.06
#
#
# ----Tuas----
#                     venue  freq
# 0             Coffee Shop   0.5
# 1    Outdoor Supply Store   0.5
# 2                     ATM   0.0
# 3  Peking Duck Restaurant   0.0
# 4            Night Market   0.0
#
#
# ----Western Water Catchment----
#           venue  freq
# 0     Gun Range   1.0
# 1           ATM   0.0
# 2        Museum   0.0
# 3     Newsstand   0.0
# 4  Night Market   0.0
#
#
# ----Woodlands----
#                   venue  freq
# 0   Japanese Restaurant  0.08
# 1                  Café  0.06
# 2           Coffee Shop  0.06
# 3           Supermarket  0.04
# 4  Fast Food Restaurant  0.04
#
#
# ----Yishun----
#                   venue  freq
# 0            Food Court  0.13
# 1    Chinese Restaurant  0.07
# 2           Coffee Shop  0.04
# 3   Fried Chicken Joint  0.04
# 4  Fast Food Restaurant  0.04

# %% [markdown]
# This information can also be put into a dataframe showing the top ten most common venues for each Singaporean neighborhood.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = singapore_grouped['Neighborhood']

for ind in np.arange(singapore_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(singapore_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted
# Out:
#                Neighborhood 1st Most Common Venue  \
# 0                Ang Mo Kio           Coffee Shop
# 1                     Bedok           Coffee Shop
# 2                    Bishan            Food Court
# 3                  Boon Lay   Japanese Restaurant
# 4               Bukit Batok           Coffee Shop
# 5               Bukit Merah    Chinese Restaurant
# 6             Bukit Panjang      Sushi Restaurant
# 7               Bukit Timah                 Trail
# 8   Central Water Catchment             Reservoir
# 9                    Changi               Airport
# 10               Changi Bay         Boat or Ferry
# 11            Choa Chu Kang            Food Court
# 12                 Clementi            Food Court
# 13            Downtown Core          Concert Hall
# 14                  Geylang    Chinese Restaurant
# 15                  Hougang            Food Court
# 16              Jurong East                  Café
# 17              Jurong West   Japanese Restaurant
# 18                  Kallang            Restaurant
# 19             Lim Chu Kang           Zoo Exhibit
# 20                   Mandai      Asian Restaurant
# 21              Marina East                  Park
# 22             Marina South                Garden
# 23            Marine Parade                 Hotel
# 24                   Museum                 Hotel
# 25                   Newton    Chinese Restaurant
# 26                   Novena           Coffee Shop
# 27                  Orchard              Boutique
# 28                   Outram                Bakery
# 29                Pasir Ris                Bakery
# 30               Paya Lebar         Shopping Mall
# 31                  Pioneer     Convenience Store
# 32                  Punggol   Japanese Restaurant
# 33               Queenstown            Food Court
# 34             River Valley                Bakery
# 35                   Rochor     Indian Restaurant
# 36                  Seletar           Snack Place
# 37                Sembawang           Coffee Shop
# 38                 Sengkang  Fast Food Restaurant
# 39                Serangoon           Coffee Shop
# 40                  Simpang                 Diner
# 41          Singapore River                 Hotel
# 42             Straits View         Boat or Ferry
# 43             Sungei Kadut           Bus Station
# 44                 Tampines                  Café
# 45                  Tanglin     French Restaurant
# 46                Toa Payoh          Noodle House
# 47                     Tuas           Coffee Shop
# 48  Western Water Catchment             Gun Range
# 49                Woodlands   Japanese Restaurant
# 50                   Yishun            Food Court
#
#             2nd Most Common Venue  3rd Most Common Venue  \
# 0                    Dessert Shop             Food Court
# 1                    Noodle House       Asian Restaurant
# 2                     Coffee Shop        Bubble Tea Shop
# 3                Asian Restaurant   Fast Food Restaurant
# 4                      Food Court     Chinese Restaurant
# 5                      Food Court            Karaoke Bar
# 6               Korean Restaurant   Fast Food Restaurant
# 7                  Scenic Lookout              Rest Area
# 8                Business Service            Zoo Exhibit
# 9                Airport Terminal                  Hotel
# 10                       Gym Pool             Smoke Shop
# 11           Fast Food Restaurant            Snack Place
# 12                    Coffee Shop       Asian Restaurant
# 13           Gym / Fitness Center                 Lounge
# 14                     Food Court           Noodle House
# 15           Fast Food Restaurant     Chinese Restaurant
# 16             Chinese Restaurant    Japanese Restaurant
# 17               Asian Restaurant   Fast Food Restaurant
# 18               Asian Restaurant                 Hostel
# 19                      Gift Shop                   Farm
# 20                    Zoo Exhibit      Fish & Chips Shop
# 21                   Home Service                   Café
# 22                     Public Art    Government Building
# 23                      Multiplex         Massage Studio
# 24                   Dessert Shop    Japanese Restaurant
# 25             Seafood Restaurant     Italian Restaurant
# 26                           Café       Asian Restaurant
# 27            Japanese Restaurant                 Bakery
# 28                    Coffee Shop     Spanish Restaurant
# 29                     Food Court         Sandwich Place
# 30           Fast Food Restaurant             Food Court
# 31                    Coffee Shop   Gym / Fitness Center
# 32             Chinese Restaurant       Sushi Restaurant
# 33                   Noodle House     Chinese Restaurant
# 34                           Café            Salad Place
# 35  Vegetarian / Vegan Restaurant     Chinese Restaurant
# 36                     Food Court                   Café
# 37           Fast Food Restaurant     Chinese Restaurant
# 38                    Bus Station             Food Court
# 39             Chinese Restaurant         Ice Cream Shop
# 40                       Platform            Zoo Exhibit
# 41            Japanese Restaurant              Nightclub
# 42                    Zoo Exhibit  General Entertainment
# 43                          Hotel            Art Gallery
# 44                         Bakery            Coffee Shop
# 45                         Bakery                   Park
# 46             Chinese Restaurant             Food Court
# 47           Outdoor Supply Store            Zoo Exhibit
# 48                    Zoo Exhibit              Gastropub
# 49                           Café            Coffee Shop
# 50             Chinese Restaurant      Hainan Restaurant
#
#             4th Most Common Venue          5th Most Common Venue  \
# 0                 Bubble Tea Shop                    Supermarket
# 1                      Food Court                 Sandwich Place
# 2                  Ice Cream Shop                 Cosmetics Shop
# 3                    Dessert Shop             Chinese Restaurant
# 4                Department Store           Fast Food Restaurant
# 5                             Gym                           Café
# 6                Asian Restaurant             Chinese Restaurant
# 7                            Hill                    Zoo Exhibit
# 8             Filipino Restaurant         Furniture / Home Store
# 9                       Rest Area                     Food Court
# 10                    Pizza Place                 History Museum
# 11                           Café                    Coffee Shop
# 12                   Dessert Shop                    Bus Station
# 13                          Hotel                      Hotel Bar
# 14  Vegetarian / Vegan Restaurant             Dim Sum Restaurant
# 15                    Supermarket                           Café
# 16                    Coffee Shop                     Food Court
# 17             Chinese Restaurant                   Dessert Shop
# 18                    Supermarket                    Coffee Shop
# 19              Fish & Chips Shop                    Gaming Cafe
# 20                         Garden                    Gaming Cafe
# 21            Filipino Restaurant         Furniture / Home Store
# 22                           Park            Filipino Restaurant
# 23            Japanese Restaurant             Chinese Restaurant
# 24                 Cosmetics Shop                Bubble Tea Shop
# 25                      Hotel Bar                   Dance Studio
# 26                          Hotel             Italian Restaurant
# 27               Sushi Restaurant                          Hotel
# 28                      Gastropub                           Café
# 29           Fast Food Restaurant                          Diner
# 30             Chinese Restaurant               Asian Restaurant
# 31               Asian Restaurant           Fast Food Restaurant
# 32                    Supermarket                 Discount Store
# 33                           Café                     Steakhouse
# 34           Fast Food Restaurant                  Movie Theater
# 35               Ramen Restaurant                           Café
# 36                Harbor / Marina                    Zoo Exhibit
# 37                    Bus Station                            ATM
# 38               Asian Restaurant                    Coffee Shop
# 39            Japanese Restaurant              Korean Restaurant
# 40            Filipino Restaurant         Furniture / Home Store
# 41                Thai Restaurant  Vegetarian / Vegan Restaurant
# 42                         Garden                    Gaming Cafe
# 43                         Office                    Zoo Exhibit
# 44                            Gym                    Supermarket
# 45                Thai Restaurant     Modern European Restaurant
# 46               Asian Restaurant                    Snack Place
# 47            Filipino Restaurant         Furniture / Home Store
# 48                    Gaming Cafe         Furniture / Home Store
# 49                  Shopping Mall              Electronics Store
# 50            Fried Chicken Joint           Fast Food Restaurant
#
#      6th Most Common Venue   7th Most Common Venue      8th Most Common Venue  \
# 0      Japanese Restaurant             Snack Place           Ramen Restaurant
# 1      Japanese Restaurant      Chinese Restaurant     Thrift / Vintage Store
# 2      Japanese Restaurant                    Café           Asian Restaurant
# 3              Coffee Shop             Bus Station          Indian Restaurant
# 4       Frozen Yogurt Shop           Shopping Mall              Bowling Alley
# 5                     Pool              Club House                       Park
# 6          Bubble Tea Shop             Supermarket              Shopping Mall
# 7           Farmers Market     Fried Chicken Joint          French Restaurant
# 8       Frozen Yogurt Shop     Fried Chicken Joint          French Restaurant
# 9              Zoo Exhibit     Filipino Restaurant     Furniture / Home Store
# 10             Zoo Exhibit      Frozen Yogurt Shop        Fried Chicken Joint
# 11            Noodle House                  Lounge            Thai Restaurant
# 12    Fast Food Restaurant      Chinese Restaurant              Shopping Mall
# 13              Waterfront             Salad Place                Coffee Shop
# 14           Grocery Store        Asian Restaurant           Department Store
# 15             Coffee Shop            Dessert Shop          Fish & Chips Shop
# 16           Shopping Mall               Multiplex     Furniture / Home Store
# 17             Coffee Shop             Bus Station          Indian Restaurant
# 18             Flea Market             Flower Shop                 Food Court
# 19  Furniture / Home Store      Frozen Yogurt Shop        Fried Chicken Joint
# 20  Furniture / Home Store      Frozen Yogurt Shop        Fried Chicken Joint
# 21      Frozen Yogurt Shop     Fried Chicken Joint          French Restaurant
# 22  Furniture / Home Store      Frozen Yogurt Shop        Fried Chicken Joint
# 23       Indian Restaurant             Supermarket         Dim Sum Restaurant
# 24              Soup Place        Sushi Restaurant               Optical Shop
# 25         Thai Restaurant       Indian Restaurant        Japanese Restaurant
# 26        Ramen Restaurant                  Bakery             Sandwich Place
# 27      Chinese Restaurant           Shopping Mall             Cosmetics Shop
# 28           Grocery Store      Seafood Restaurant             Farmers Market
# 29      Italian Restaurant        Sushi Restaurant                Supermarket
# 30            Noodle House             Coffee Shop            Bubble Tea Shop
# 31             Supermarket             Flower Shop                    Stadium
# 32          Clothing Store          Ice Cream Shop       Fast Food Restaurant
# 33                 Stadium      Seafood Restaurant              Train Station
# 34                Bus Stop              Shoe Store               Gourmet Shop
# 35              Restaurant               BBQ Joint  Middle Eastern Restaurant
# 36     Filipino Restaurant      Frozen Yogurt Shop        Fried Chicken Joint
# 37        Basketball Court     Japanese Restaurant     Furniture / Home Store
# 38        Sushi Restaurant                     Gym         Chinese Restaurant
# 39            Noodle House    Fast Food Restaurant             Clothing Store
# 40      Frozen Yogurt Shop     Fried Chicken Joint          French Restaurant
# 41              Food Court                     Bar                       Café
# 42  Furniture / Home Store      Frozen Yogurt Shop        Fried Chicken Joint
# 43       Fish & Chips Shop  Furniture / Home Store         Frozen Yogurt Shop
# 44        Sushi Restaurant           Shopping Mall       Fast Food Restaurant
# 45                  Garden               Gastropub                     Museum
# 46             Coffee Shop                    Café                 Steakhouse
# 47      Frozen Yogurt Shop     Fried Chicken Joint          French Restaurant
# 48      Frozen Yogurt Shop     Fried Chicken Joint          French Restaurant
# 49          Clothing Store      Chinese Restaurant         Frozen Yogurt Shop
# 50             Coffee Shop             Supermarket        Sporting Goods Shop
#
#             9th Most Common Venue 10th Most Common Venue
# 0                    Noodle House   Fast Food Restaurant
# 1                     Supermarket           Dessert Shop
# 2              Chinese Restaurant            Supermarket
# 3                            Café         Cosmetics Shop
# 4                            Café       Malay Restaurant
# 5                   Bowling Alley              Cable Car
# 6                     Bus Station     Seafood Restaurant
# 7                      Food Stand           Food Service
# 8                      Food Stand           Food Service
# 9              Frozen Yogurt Shop    Fried Chicken Joint
# 10              French Restaurant             Food Stand
# 11                 Sandwich Place                 Bakery
# 12                   Noodle House        Thai Restaurant
# 13          Performing Arts Venue           Cocktail Bar
# 14           Fast Food Restaurant           Dessert Shop
# 15               Sushi Restaurant              Bookstore
# 16                 Sandwich Place         Clothing Store
# 17                Bubble Tea Shop                   Café
# 18                   Food Service            Zoo Exhibit
# 19              French Restaurant             Food Stand
# 20              French Restaurant             Food Stand
# 21                     Food Stand           Food Service
# 22              French Restaurant             Food Stand
# 23                         Bakery                   Café
# 24                     Restaurant                    Spa
# 25           Gym / Fitness Center          Grocery Store
# 26                    Supermarket      Hainan Restaurant
# 27               Asian Restaurant  Indonesian Restaurant
# 28                     Nail Salon     Dim Sum Restaurant
# 29                     Restaurant            Golf Course
# 30                    Supermarket    Fried Chicken Joint
# 31             Seafood Restaurant               Bus Stop
# 32             Light Rail Station             Food Court
# 33  Vegetarian / Vegan Restaurant            Coffee Shop
# 34                     Steakhouse            Men's Store
# 35               Sushi Restaurant            Gaming Cafe
# 36              French Restaurant             Food Stand
# 37                    Pizza Place             Playground
# 38               Sculpture Garden          Metro Station
# 39          Indonesian Restaurant        Bubble Tea Shop
# 40                     Food Stand           Food Service
# 41             Italian Restaurant           Noodle House
# 42              French Restaurant             Food Stand
# 43            Fried Chicken Joint      French Restaurant
# 44                Bubble Tea Shop    Japanese Restaurant
# 45                        Brewery     Seafood Restaurant
# 46                Thai Restaurant           Dessert Shop
# 47                     Food Stand           Food Service
# 48                     Food Stand           Food Service
# 49           Fast Food Restaurant      Indian Restaurant
# 50                   Noodle House                   Café

# %% [markdown]
# Next, we would like to rank the neighborhoods in terms of number of gyms.

# %%
singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()

# %% [markdown]
# Let us look at the top six Singaporean neighborhoods with the most gyms.

# %%
neighborhoodsMostGyms = singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:6]          
for index,value in neighborhoodsMostGyms.iteritems():
    print(value)

# %% [markdown]
# Let us plot these neighborhoods on a map.

# %%
address = 'Singapore'

#Get the latitude and longitude of Singapore
geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# create map of New York using latitude and longitude values
map_singapore = folium.Map(location=[latitude, longitude], zoom_start=10)

#add markers to map
neighborhoodsMostGyms = singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:6]          
for index,value in neighborhoodsMostGyms.iteritems():
    neighborhood = value
    lat = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Latitude'].iloc[0]
    lng = planningArea_data.loc[planningArea_data['Planning Area'] == value, 'Longitude'].iloc[0]    
    label = neighborhood
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)  
    
map_singapore

# %% [markdown]
# Next, we can look at which neighborhoods have the most malls.

# %%
singapore_venues[singapore_venues["Venue Category"] == 'Shopping Mall']

# %%
singapore_venues[singapore_venues["Venue Category"] == 'Shopping Mall'].value_counts(subset=['Neighborhood'])

# %%
neighborhoodsMostGyms = singapore_venues[(singapore_venues["Venue Category"] == 'Gym') | (singapore_venues["Venue Category"] == 'Gym / Fitness Center')].value_counts(subset=['Neighborhood']).to_frame().reset_index()['Neighborhood'][0:6]
